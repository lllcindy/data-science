# %% [markdown]
# # Text Classification
#
# In this problem, you will be analyzing the Twitter data we extracted using [this](https://dev.twitter.com/overview/api) api. This time, we extracted the tweets posted by the following six Twitter accounts: `realDonaldTrump, mike_pence, GOP, HillaryClinton, timkaine, TheDemocrats`.
#
# For every tweet, we collected two pieces of information:
# - `screen_name`: the Twitter handle of the user tweeting and
# - `text`: the content of the tweet.
#
# We divided the tweets into two parts - the train and test sets.  The training set contains both the `screen_name` and `text` of each tweet; the test set only contains the `text`.
#
# The overarching goal of the problem is to infer the political inclination (whether **R**epublican or **D**emocratic) of the author from the tweet text. The ground truth (i.e., true class labels) are determined from the `screen_name` of the tweet as follows:
# - **R**: `realDonaldTrump, mike_pence, GOP`
# - **D**: `HillaryClinton, timkaine, TheDemocrats`
#
# We can treat this as a binary classification problem. We'll follow this common structure to tackling this problem:
#
# 1. **preprocessing**: clean up the raw tweet text using the various functions offered by [the Natural Language Toolkit (`nltk`)](http://www.nltk.org/genindex.html).
# 2. **features**: construct bag-of-words feature vectors.
# 3. **classification**: learn a binary classification model using [`scikit-learn`](http://scikit-learn.org/stable/modules/classes.html).
#
# Note that `nltk` supports optional corpora, toy grammars, trained models, etc. For this assignment, you have to manually install the stopwords list and `WordNetLemmatizer`. We'll begin by installing them:

# %%
import nltk
import collections
import string
import numpy as np
import sklearn
import gzip
import csv
import re
import matplotlib.pyplot as plt

from testing.testing import test

def nltk_download_test(nltk_download):
    nltk_download()
    try:
        lemmatizer=nltk.stem.wordnet.WordNetLemmatizer()
        test.true(lemmatizer is not None)
        stopwords=nltk.corpus.stopwords.words('english')
        test.true(stopwords is not None)
    except LookupError:
        test.true(False)
        
@test
def nltk_download():
    nltk.download('stopwords')
    nltk.download('wordnet')
    nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Xindi\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Xindi\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Xindi\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# ### TESTING nltk_download: PASSED 2/2
# ###

# %% [markdown]
# ## 1. Text Processing
#
# You first task to fill in the following function which processes and tokenizes raw text. The tokens must:
#
# 1. be in lower case.
# 2. appear in the same order as in the raw text.
# 3. be in their lemmatized form, if one exists. If a word cannot be lemmatized, do not include it in the output.
# 4. **not** contain any characters other than numbers and digits; you should:
#    1. remove trailing `'s`: `Children's` becomes `children`
#    2. omit other apostrophes: `don't` becomes `dont`
#    3. break tokens at other punctuation and/or unicode characters: `word-of-mouth` becomes `word`, `of`, `mouth`
# 5. if the lemmatized form is a stopword, it should not appear in the output
# 6. not include the parts of any t.co urls. Many tweets contain URLs from the domain `t.co`; you should strip all such URLs.
#
# If you figure out the right order to perform these operations, solving this problem is much easier.
#
# **Stopwords** are words that appear very often in text, usually playing a grammatical role ("and", "a", etc.). When comparing text similarity, these are not very useful; so we eliminate them at this stage. (NLTK provides us with a list of stopwords for English, which we will use later.)
#
# Hints:
#
#  - `string.punctuation` is a string of all the punctuation symbols
#  - you should use `nltk.word_tokenize()` in your solution
#  - you should break tokens at all characters that are not in `string.ascii_letters` or `string.digits`
#  - test your URL stripping! It's very easy to make a mistake with it.

# %%
def preprocess_test(preprocess):
    test.equal(preprocess("I'm doing well! How about you?"), ['im', 'doing', 'well', 'how', 'about', 'you'])
    test.equal(preprocess("Education is the ability to listen to almost anything without losing your temper or your self-confidence."),    ['education', 'is', 'the', 'ability', 'to', 'listen', 'to', 'almost', 'anything', 'without', 'losing', 'your', 'temper', 'or', 'your', 'self', 'confidence'])

    # Punctuation and space handling
    test.equal(preprocess(" a..a. .a . a."), ['a', 'a', 'a', 'a'])
    test.equal(preprocess("word-of-mouth self-esteem"), ['word', 'of', 'mouth', 'self', 'esteem'])

    # Apostrophe handling
    test.equal(preprocess("you've"), ['youve'])
    test.equal(preprocess("She's"), ['she'])
    test.equal(preprocess("Cea'sar"), ['ceaar']) # You can assume that there are no mid-word "'s" substrings.

    # Lemmatizer
    test.equal(preprocess("walks"), ['walk'])
    
    # Stopwords
    stopwords = set(nltk.corpus.stopwords.words('english'))
    test.equal(preprocess("I'm doing well! How about you?", stopwords), ['im', 'well'])
    test.equal(preprocess("Education is the ability to listen to almost anything without losing your temper or your self-confidence.", stopwords), ['education', 'ability', 'listen', 'almost', 'anything', 'without', 'losing', 'temper', 'self', 'confidence'])

    # Unicode handling
    test.equal(preprocess("doot👏doot"), ["doot", "doot"])

    # URL handling
    test.equal(preprocess("http://t.co/WJs5bmRthU,http://t.co/WJs5bmRthU,"), [])
    test.equal(preprocess("boohttp://t.co/WJs5bmRthUhello"), ["boo", "hello"])
    
    test.equal(preprocess("SHE'S"), ['she'])
    test.equal(preprocess("https://t.co/ZhEyÄ¶aaaa"), ['http', 't', 'co', 'zhey', 'aaaa'])
    test.equal(preprocess("http://t.co/WJs5bmRthU,https://t.co/WJs5bmRthU,"), [])
    test.equal(preprocess("https://t.co/ZhEyÄ¶aaaa"), ['http', 't', 'co', 'zhey', 'aaaa'])
    test.equal(preprocess("https://t.co/WJs5bmRth-"), ['http', 't', 'co', 'wjs5bmrth'])

@test
def preprocess(text, stopwords={}, lemmatizer=nltk.stem.wordnet.WordNetLemmatizer()):
    """ Normalizes case and handles punctuation
    
    args:
        text: str -- raw text
        stopwords : Set[str] -- lemmatized tokens to exclude from the output
        lemmatizer : Lemmatizer -- an instance of a class implementing the lemmatize() method

    Outputs:
        list(str): tokenized text
    """
    text=text.lower()
    s=re.sub("'s?", "", text)
    s=re.sub(r"https?://t.co/[abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ0123456789]{10}", " ", s)
    s1=re.sub(r"[^abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ0123456789]", " ", s)
    l=nltk.word_tokenize(s1)
    l1=nltk.word_tokenize(s1)
    for i in l:
        l1.remove(i)
        i=lemmatizer.lemmatize(i)
        if i in stopwords:
            pass
        else:    
            l1.append(i)
    return l1
    pass
# Out:
# ### TESTING preprocess: PASSED 18/18
# ###

# %% [markdown]
# We give you some code that uses `preprocess` to prepare the data. This should take no more than 6s to run; if it takes longer than that, you need to make your preprocessing function run quicker.

# %%
# %%timeit
## Uncomment the previous line to time your code. Remember to comment it out before uploading your solution.

def read_data_test(read_data):
    data_train, data_test = read_data()
    
    test.equal(len(data_train), 17298)
    test.equal(len(data_test), 1000)

def read_csv(stem, process=lambda x: x):
    with gzip.open(f"{stem}.csv.gz", "rt", newline='', encoding="UTF-8") as file:
        csvr = csv.reader(file)
        next(csvr)
        return list(map(process, csvr))

def is_republican(r):
    return r in ["realDonaldTrump", "mike_pence", "GOP"]

@test
def read_data(extra_stopwords=set()):
    """Reads the dataset from the csv.gz files
    
    return : Tuple[data_train, data_test]
        data_train : List[Tuple[is_republican, tokenized_tweet]]
            is_republican : bool -- True if tweet is from a republican
            tokenized_tweet : List[str] -- the tweet, tokenized by preprocess()
    """
    stopwords = set(nltk.corpus.stopwords.words('english')) | set(["http", "co", "rt", "amp"]) | extra_stopwords  
    data_train = read_csv("tweets_train", process=lambda r: (is_republican(r[0]), preprocess(r[1], stopwords)))
    data_test = read_csv("tweets_test", process=lambda r: preprocess(r[0], stopwords))
    return (data_train, data_test)
# Out:
# ### TESTING read_data: PASSED 2/2
# ###

# %%
data_train, data_test = read_data()

# %%
data_train
# Out:
# [(True,
#   ['gopconvention',
#    'oregon',
#    'vote',
#    'today',
#    'mean',
#    '62',
#    'day',
#    'gopconvention']),
#  (False,
#   ['dwstweets',
#    'choice',
#    '2016',
#    'clear',
#    'need',
#    'another',
#    'democrat',
#    'white',
#    'house',
#    'demdebate',
#    'wearedemocrats']),
#  (False,
#   ['trump',
#    'calling',
#    'trillion',
#    'dollar',
#    'tax',
#    'cut',
#    'wall',
#    'street',
#    'time',
#    'pay',
#    'fair',
#    'share']),
#  (False,
#   ['timkaine',
#    'guiding',
#    'principle',
#    'belief',
#    'make',
#    'difference',
#    'public',
#    'service']),
#  (False,
#   ['glad',
#    'senate',
#    'could',
#    'pas',
#    'thud',
#    'milcon',
#    'vetaffairs',
#    'approps',
#    'bill',
#    'solid',
#    'provision',
#    'virginia']),
#  (True,
#   ['indythisweek',
#    'rtv6',
#    'exclusive',
#    'govpencein',
#    'sits',
#    'rafaelontv',
#    'see',
#    'sunday',
#    'morning',
#    '8',
#    '30a',
#    'rtv6',
#    'rtv6',
#    'app']),
#  (False,
#   ['chatham',
#    'town',
#    'council',
#    'congress',
#    'reproberthurt',
#    'ha',
#    'made',
#    'strong',
#    'mark',
#    'community',
#    'proud',
#    'work',
#    'together',
#    'behalf',
#    'va']),
#  (True,
#   ['thank',
#    'new',
#    'orleans',
#    'louisiana',
#    'makeamericagreatagain',
#    'votetrump']),
#  (True, ['realdonaldtrump', 'happy', '241st', 'birthday', 'usarmy', 'thank']),
#  (True,
#   ['govpencein',
#    'excited',
#    'announce',
#    'today',
#    'plan',
#    'build',
#    'indiana',
#    'neuro',
#    'diagnostic',
#    'institute',
#    'partnership',
#    'w',
#    'chnw',
#    'hy4yrc']),
#  (False,
#   ['sensanders',
#    'dad',
#    'wa',
#    'born',
#    'poland',
#    'know',
#    'many',
#    'people',
#    'ever',
#    'asked',
#    'whether',
#    'wa',
#    'born',
#    'america',
#    'nobody',
#    'ever',
#    'aske']),
#  (False,
#   ['positive',
#    'relationship',
#    'faith',
#    'group',
#    'law',
#    'enforcement',
#    'build',
#    'resilient',
#    'community']),
#  (False, ['weekendvibes']),
#  (False,
#   ['welcomed',
#    'stevecase',
#    'riseofrest',
#    'tour',
#    'rva',
#    'morning',
#    'talk',
#    'innovation',
#    'talent',
#    'entrepreneurial',
#    'drive']),
#  (False,
#   ['take',
#    'president',
#    'republican',
#    'party',
#    'dangerously',
#    'extreme',
#    'betterthanthis']),
#  (True, ['watching', 'demdebate', 'dont', 'dont', 'want']),
#  (False,
#   ['next',
#    'president',
#    'spouse',
#    'big',
#    'job',
#    'campaign',
#    'trail',
#    'white',
#    'house',
#    'followfriday',
#    'janeosanders',
#    'billclinton']),
#  (True, ['obama', 'losing', 'credibility', 'syrian', 'opposition', 'leader']),
#  (False,
#   ['congratulation',
#    'judge',
#    'hannah',
#    'lauck',
#    'virginia',
#    'confirmed',
#    'eastern',
#    'district',
#    'court',
#    '90',
#    '0',
#    'vote']),
#  (False,
#   ['wrote',
#    'usindianaffairs',
#    'calling',
#    'flexibility',
#    'federal',
#    'recognition',
#    'process',
#    'indian',
#    'tribe',
#    'unusual',
#    'circumstance']),
#  (False,
#   ['congrats',
#    'va',
#    'national',
#    'guard',
#    'wwii',
#    'army',
#    'veteran',
#    'cary',
#    'jarvis',
#    'decorated',
#    'knight',
#    'legion',
#    'honor',
#    'french',
#    'government']),
#  (True,
#   ['leaving',
#    'new',
#    'hampshire',
#    'big',
#    'crowd',
#    'looking',
#    'forward',
#    'fitn']),
#  (False,
#   ['congrats',
#    'finalfive',
#    'outstanding',
#    'performance',
#    'rio',
#    'special',
#    'congrats',
#    'virginia',
#    'native',
#    'gabrielledoug']),
#  (False,
#   ['governorva',
#    'morning',
#    'gov',
#    'signed',
#    'eo50',
#    'taking',
#    'executive',
#    'action',
#    'keep',
#    'gun',
#    'dangerous',
#    'hand']),
#  (False,
#   ['tune',
#    'wamu885',
#    'morning',
#    'commute',
#    'interview',
#    'w',
#    'trulldc',
#    'kid',
#    'fleeing',
#    'violence',
#    'honduras']),
#  (False,
#   ['lakeannees',
#    'senator',
#    'tim',
#    'kaine',
#    'read',
#    'spanish',
#    '3rd',
#    'grade',
#    'spanish',
#    'immersion',
#    'class',
#    'today',
#    'hispanicheritagemonth',
#    'chpjay']),
#  (True, ['foxandfriends', '7', '00', 'enjoy']),
#  (True,
#   ['cjcboi',
#    'drjamescabot',
#    'realdonaldtrump',
#    'danscavino',
#    'carolde',
#    'playstrumpcard',
#    'checked',
#    'wallet',
#    'lately',
#    'mr',
#    'ailes']),
#  (False,
#   ['heading',
#    'senate',
#    'floor',
#    'make',
#    'case',
#    'keystonexl',
#    'watch',
#    'speech',
#    'live']),
#  (True,
#   ['timkaine',
#    'falsely',
#    'claim',
#    'clintonfdn',
#    'already',
#    'stopped',
#    'taking',
#    'foreign',
#    'corporate']),
#  (False,
#   ['great',
#    'bfast',
#    'roanoke',
#    'staple',
#    'next',
#    'citizen',
#    'day',
#    'clean',
#    'blue',
#    'ridge',
#    'pkwy',
#    'join',
#    'u',
#    'mile',
#    'marker',
#    '114',
#    '9']),
#  (False,
#   ['donald',
#    'trump',
#    'launched',
#    'campaign',
#    'one',
#    'year',
#    'ago',
#    'week',
#    'year']),
#  (False,
#   ['show',
#    'friend',
#    'party',
#    'creates',
#    'job',
#    'spoiler',
#    'isnt',
#    'trump',
#    'gop']),
#  (False,
#   ['good',
#    'news',
#    'pneumonia',
#    'finally',
#    'got',
#    'republican',
#    'interested',
#    'woman',
#    'health',
#    'hillary']),
#  (False,
#   ['whitehouse',
#    'happening',
#    'youtubeasksobama',
#    'question',
#    'potus',
#    'final',
#    'state',
#    'union']),
#  (False,
#   ['learned',
#    'family',
#    'methodist',
#    'faith',
#    'called',
#    'good',
#    'people',
#    'hillary']),
#  (True,
#   ['govpencein',
#    'never',
#    'fully',
#    'repay',
#    'debt',
#    'deputy',
#    'koontz',
#    'service',
#    'county',
#    'state',
#    'nation',
#    'h']),
#  (False,
#   ['study',
#    'show',
#    'rate',
#    'sea',
#    'level',
#    'rise',
#    'accelerating',
#    'pose',
#    'serious',
#    'challenge',
#    'hampton',
#    'road',
#    'actonclimate']),
#  (True,
#   ['abcpolitics',
#    'mike',
#    'penny',
#    'clinton',
#    'deleted',
#    'email',
#    'doesnt',
#    'look',
#    'like',
#    'politics',
#    'folk',
#    'look',
#    'like',
#    'obstruction']),
#  (True,
#   ['landed',
#    'baton',
#    'rouge',
#    'louisiana',
#    'report',
#    'line',
#    'three',
#    'quarter',
#    'mile',
#    'get',
#    'wow',
#    'makeamericagreatagain']),
#  (True, ['sign', 'agree', 'speaker', 'ryan']),
#  (False,
#   ['honored',
#    'speak',
#    'veteran',
#    'family',
#    'george',
#    'marshall',
#    'international',
#    'center',
#    'leesburg',
#    'veteransday']),
#  (True, ['iowa', 'went', 'wrong', 'hillary', 'clinton']),
#  (True,
#   ['virginiajim16',
#    'public',
#    'service',
#    'announcement',
#    'people',
#    'va',
#    'check',
#    'door',
#    'teamva',
#    'vol',
#    'looking',
#    'chat',
#    'leadright2016']),
#  (False,
#   ['weve', 'got', 'make', 'economy', 'work', 'everyone', 'top', 'hillary']),
#  (False,
#   ['hillaryforfl',
#    'rania',
#    'doesnt',
#    'understand',
#    'country',
#    'great',
#    'united',
#    'state',
#    'ha',
#    'never',
#    'woman',
#    'president',
#    'imwithher']),
#  (False,
#   ['never',
#    'campaign',
#    'app',
#    'like',
#    'download',
#    'today',
#    'help',
#    'hillary',
#    'win']),
#  (True,
#   ['govpencein',
#    'week',
#    'firstladyin',
#    'enjoyed',
#    'one',
#    'favorite',
#    'summer',
#    'pastime']),
#  (False,
#   ['go',
#    'woman',
#    'go',
#    'literally',
#    'every',
#    'group',
#    'im',
#    'going',
#    'voice',
#    'hillary',
#    'trump']),
#  (True,
#   ['preparing', 'delicious', 'meal', 'kosciusko', 'county', 'republican']),
#  (True,
#   ['past',
#    'several',
#    'year',
#    'almost',
#    '80',
#    '000',
#    'hoosier',
#    'entered',
#    'workforce',
#    'read',
#    'injobs']),
#  (True,
#   ['seven', 'additional', 'clinton', 'email', 'marked', 'top', 'secret']),
#  (False,
#   ['sarajacobs89',
#    'gop',
#    'care',
#    'defunding',
#    'ppfa',
#    'protecting',
#    'confederate',
#    'flag',
#    'protecting',
#    'million',
#    'zika']),
#  (True,
#   ['rga',
#    'tech',
#    'firm',
#    'bolt',
#    'california',
#    'mike',
#    'penny',
#    'pro',
#    'business',
#    'indiana',
#    'ingov',
#    'astatethatworks']),
#  (True,
#   ['lgholcomb',
#    'cereal',
#    'indiana',
#    'thing',
#    'indiana',
#    'grown',
#    'granola',
#    'ims',
#    'milk',
#    'lunch',
#    'celebration',
#    'nationalcerealday',
#    'h']),
#  (True,
#   ['low',
#    'energy',
#    'jeb',
#    'bush',
#    'endorsed',
#    'man',
#    'truly',
#    'hate',
#    'lyin',
#    'ted',
#    'cruz',
#    'honestly',
#    'blame',
#    'jeb',
#    'drove',
#    'oblivion']),
#  (False,
#   ['hosted',
#    'great',
#    'citizen',
#    'day',
#    'volunteer',
#    'initiative',
#    'w',
#    'colonial',
#    'height',
#    'food',
#    'pantry',
#    'distribute',
#    'food',
#    'resident',
#    'need']),
#  (False,
#   ['hillaryforoh',
#    'smile',
#    'count',
#    'hillaryclinton',
#    'elizabeth',
#    'warren',
#    'take',
#    'stage',
#    'cincy',
#    'ohhillyes',
#    'f']),
#  (False,
#   ['shocked',
#    'saddened',
#    'today',
#    'violent',
#    'terror',
#    'attack',
#    'tel',
#    'aviv',
#    'u',
#    'stand',
#    'israel',
#    'mourning',
#    'loss',
#    'life',
#    'seeking',
#    'justice']),
#  (True, ['thank', 'dallaspd']),
#  (False,
#   ['thanks',
#    'roanoketimes',
#    'writing',
#    'im',
#    'fighting',
#    'new',
#    'aumf',
#    'one',
#    'year',
#    'unauthorized',
#    'war',
#    'v',
#    'isil']),
#  (False,
#   ['tire',
#    'manufacturer',
#    'salem',
#    'know',
#    'wrongdoing',
#    'chinese',
#    'trade',
#    'practice',
#    'markwarner',
#    'know']),
#  (False,
#   ['thank',
#    'dedicated',
#    'nurse',
#    'care',
#    'sick',
#    'elderly',
#    'veteran',
#    'need',
#    'nursesday',
#    'nursesweek']),
#  (True,
#   ['talking',
#    'wonderful',
#    'experience',
#    'iowa',
#    'simultaneous',
#    'unfair',
#    'treatment',
#    'medium',
#    'later',
#    'new',
#    'hampshire',
#    'big',
#    'crowd']),
#  (False,
#   ['hillaryclinton',
#    'think',
#    'trump',
#    'involved',
#    '5',
#    '500',
#    'lawsuit',
#    'going',
#    'try',
#    'read',
#    '4',
#    'hour']),
#  (True, ['nobody', 'beat', 'national', 'security']),
#  (False,
#   ['becoming',
#    'party',
#    'trump',
#    'gop',
#    'ha',
#    'completely',
#    'abandoned',
#    'american',
#    'middle',
#    'class']),
#  (False,
#   ['hillaryforga',
#    'trump',
#    'see',
#    'american',
#    'respect',
#    'american',
#    'serve',
#    'american',
#    'strongertogether']),
#  (False,
#   ['every', 'time', 'get', 'campaign', 'event', 'anne', 'like', 'vacation']),
#  (True,
#   ['walkwalka25',
#    'scotus',
#    'nomination',
#    'go',
#    'american',
#    'people',
#    'voter',
#    'windham',
#    'signing',
#    'agreement',
#    'leadright2016']),
#  (True,
#   ['nation',
#    'largest',
#    'coal',
#    'company',
#    'go',
#    'bankrupt',
#    'hillary',
#    'supporter',
#    'john',
#    'gregg',
#    'keep',
#    'head',
#    'sand',
#    'rga']),
#  (True,
#   ['hillaryclinton',
#    'couldnt',
#    'stop',
#    'sending',
#    'classified',
#    'info',
#    'left',
#    'state',
#    'dept']),
#  (False,
#   ['hillaryforwi',
#    'breaking',
#    'timkaine',
#    'milwaukee',
#    'friday',
#    'reserve',
#    'spot',
#    'wutix']),
#  (True, ['thank', 'montana', 'trump2016']),
#  (False,
#   ['appreciate',
#    'potus',
#    'call',
#    'aumf',
#    'congress',
#    'let',
#    'another',
#    'year',
#    'go',
#    'without',
#    'debating',
#    'authorizing',
#    'war',
#    'v',
#    'isil',
#    'sotu']),
#  (False, ['read', 'letter', 'secretary', 'ash', 'carter']),
#  (True,
#   ['cruz',
#    'campaign',
#    'issued',
#    'dishonest',
#    'deceptive',
#    'get',
#    'vote',
#    'ad',
#    'calling',
#    'voter',
#    'violation',
#    'investigation',
#    'bad']),
#  (False,
#   ['trump',
#    'may',
#    'talk',
#    'big',
#    'game',
#    'trade',
#    'approach',
#    'based',
#    'fear',
#    'strength',
#    'fear',
#    'compete',
#    'rest',
#    'world']),
#  (True,
#   ['clinton',
#    'take',
#    'campaign',
#    'cash',
#    'drug',
#    'industry',
#    'enemy',
#    'demdebate']),
#  (True, ['network', 'low', 'rating', 'cnn', 'fair', 'exciting']),
#  (True,
#   ['stop',
#    'hillary',
#    'big',
#    'gov',
#    'proposal',
#    'must',
#    'take',
#    'back',
#    'white',
#    'house',
#    '2016']),
#  (False,
#   ['berniesanders',
#    'got',
#    'defeat',
#    'donald',
#    'trump',
#    'everything',
#    'elect',
#    'hillary',
#    'clinton',
#    'white',
#    'house',
#    'demsinphilly']),
#  (True, ['dont', 'want', 'hillary', 'clinton', 'president', 'reason']),
#  (True,
#   ['state',
#    'dept',
#    'staffer',
#    'worked',
#    'hillary',
#    'secret',
#    'email',
#    'server',
#    'face',
#    'subpoena',
#    'pleads',
#    '5th']),
#  (True,
#   ['reince',
#    'florida',
#    'visit',
#    'hillary',
#    'clinton',
#    'show',
#    'still',
#    'touch']),
#  (False,
#   ['century',
#    'trying',
#    'declared',
#    'health',
#    'care',
#    'america',
#    'privilege',
#    'right',
#    'everybody',
#    'pres',
#    'obama']),
#  (True,
#   ['govpencein',
#    'pleased',
#    'attorney',
#    'general',
#    'working',
#    'attorney',
#    'general',
#    'across',
#    'country',
#    'invalidate',
#    'regulati']),
#  (True,
#   ['ausbiz',
#    'realdonaldtrump',
#    'trump',
#    'impressive',
#    'politician',
#    'ha',
#    'passion',
#    'energy',
#    'makeamericagreatagain']),
#  (True,
#   ['goofy',
#    'elizabeth',
#    'warren',
#    'phony',
#    'native',
#    'american',
#    'heritage',
#    'twitter',
#    'rant',
#    'easy',
#    'im',
#    'driving',
#    'nut']),
#  (True,
#   ['walmart',
#    'employ',
#    'around',
#    '36',
#    '000',
#    'hoosier',
#    'opening',
#    'ecommerce',
#    'center',
#    'plainfield',
#    'indiana']),
#  (True,
#   ['amandaeseth',
#    'way',
#    'gopdebate',
#    'awesome',
#    'volunteer',
#    'leadright2016',
#    'teamfl',
#    'rnc',
#    'rpof',
#    'hannah',
#    'l',
#    'hughes',
#    'b80k']),
#  (False,
#   ['well',
#    'reward',
#    'company',
#    'share',
#    'profit',
#    'employee',
#    'pay',
#    'good',
#    'wage',
#    'executive',
#    'worker']),
#  (False,
#   ['headed',
#    'trucon15',
#    'speak',
#    'future',
#    'america',
#    'role',
#    'world',
#    'global',
#    'engagement',
#    'passing',
#    'new',
#    'aumf',
#    'v',
#    'isil',
#    'trumanproject']),
#  (True,
#   ['hillary',
#    'struggle',
#    'connect',
#    'w',
#    'dems',
#    'campaign',
#    'trail',
#    'stophillary']),
#  (True,
#   ['govpencein',
#    'next',
#    'generation',
#    'hoosier',
#    'educator',
#    'scholarship',
#    'aim',
#    'attract',
#    'top',
#    'performing',
#    'student',
#    'teaching',
#    'profession',
#    'c']),
#  (False,
#   ['keep', 'asking', 'kind', 'person', 'want', 'handle', 'nuclear', 'code']),
#  (True,
#   ['economic',
#    'success',
#    'caused',
#    'unemployment',
#    'rate',
#    'tumble',
#    '5',
#    'first',
#    'time',
#    '7',
#    'year']),
#  (True,
#   ['indiana',
#    'edc',
#    'merchandise',
#    'warehouse',
#    '3rd',
#    'generation',
#    'family',
#    'owned',
#    'biz',
#    'investing',
#    '13',
#    '8m',
#    'operation',
#    'creating',
#    '65',
#    'job']),
#  (False,
#   ['dacaworks',
#    'virginia',
#    'way',
#    'senate',
#    'floor',
#    'tell',
#    'story',
#    'va',
#    'dreamer',
#    'benefiting',
#    'daca',
#    'program']),
#  (True,
#   ['fallout',
#    'hillary',
#    'clinton',
#    'email',
#    'scandal',
#    'likely',
#    'complicate',
#    'campaign',
#    'month']),
#  (True,
#   ['hillary',
#    'clinton',
#    'campaign',
#    'seems',
#    'increasingly',
#    'desperate',
#    'reckless']),
#  (False,
#   ['good',
#    'morning',
#    'richmond',
#    'joining',
#    'jimmy',
#    '1140wrva',
#    'talk',
#    'aumf',
#    'trade',
#    'week',
#    'washington',
#    'tune']),
#  (True,
#   ['rule',
#    'change',
#    'colorado',
#    'shortly',
#    'entered',
#    'race',
#    'june',
#    'pol',
#    'boss',
#    'knew',
#    'would',
#    'win',
#    'voter']),
#  (True,
#   ['jennaknepper',
#    'check',
#    'x',
#    'ambassador',
#    'song',
#    'pick',
#    'made',
#    'leadright2016',
#    'playlist']),
#  (False,
#   ['anyone',
#    'willing',
#    'sink',
#    'low',
#    'often',
#    'never',
#    'allowed',
#    'serve',
#    'commander',
#    'chief']),
#  (True,
#   ['happy',
#    'armed',
#    'force',
#    'day',
#    'thank',
#    'member',
#    'armed',
#    'force',
#    'serve',
#    'support',
#    'great',
#    'country']),
#  (True,
#   ['thanks',
#    'rep',
#    'steve',
#    'king',
#    'support',
#    'trumppence',
#    'put',
#    'american',
#    'job',
#    '1st',
#    'make',
#    'america',
#    'great']),
#  (False,
#   ['voted',
#    'clean',
#    'cr',
#    'keep',
#    'government',
#    'open',
#    'avoids',
#    'another',
#    'needle',
#    'shutdown']),
#  (False,
#   ['want',
#    'get',
#    'involved',
#    'democratic',
#    'politics',
#    'looking',
#    'fall',
#    'intern',
#    'learn']),
#  (True,
#   ['kamilahprince',
#    'cleveland',
#    'getting',
#    'ready',
#    'committed2community',
#    'chat',
#    'gopdebate',
#    'leadright2016']),
#  (True,
#   ['thx',
#    'american',
#    'legion',
#    'post',
#    '610',
#    'hosting',
#    'realdonaldtrump',
#    'roundtable',
#    'w',
#    'labor',
#    'leader',
#    'laborday']),
#  (True,
#   ['rogerstone', 'wa', 'banned', 'cnn', 'loss', 'tough', 'loyal', 'guy']),
#  (False,
#   ['voted',
#    'bipartisan',
#    'northkorea',
#    'sanction',
#    'bill',
#    'potus',
#    'must',
#    'tool',
#    'needed',
#    'confront',
#    'growing',
#    'threat']),
#  (False,
#   ['wishing',
#    'happy',
#    'healthy',
#    'new',
#    'year',
#    'everyone',
#    'observing',
#    'rosh',
#    'hashanah']),
#  (True,
#   ['sueellspermann',
#    'evansville',
#    'proud',
#    'home',
#    'tech',
#    'center',
#    'global',
#    'leader',
#    'appliance',
#    'haier',
#    'southwestin',
#    'indiana',
#    'edc']),
#  (True,
#   ['truly',
#    'awe',
#    'every',
#    'time',
#    'meet',
#    'great',
#    'men',
#    'woman',
#    'family',
#    'sacrificed',
#    'much',
#    'u']),
#  (False,
#   ['mikereedschmidt',
#    'happy',
#    'anniversary',
#    'dodd',
#    'frank',
#    'one',
#    'candidate',
#    'would',
#    'repeal',
#    'wall',
#    'st',
#    'reform',
#    'wont',
#    'let',
#    'happen',
#    'ask',
#    'guy',
#    'h']),
#  (False,
#   ['trump',
#    'stood',
#    'proposed',
#    'muslim',
#    'ban',
#    'last',
#    'week',
#    'trying',
#    'backpedal',
#    'dont',
#    'let']),
#  (True,
#   ['full',
#    'house',
#    'outside',
#    'atlanta',
#    'ga',
#    'congressman',
#    'tom',
#    'price',
#    'bring',
#    'back',
#    'u',
#    'job',
#    'maga']),
#  (True, ['great', 'dyngusday', 'northern', 'indiana']),
#  (True,
#   ['govpencein',
#    'pleased',
#    'sign',
#    'hea',
#    '1001',
#    'evansville',
#    'commits',
#    '1',
#    'billion',
#    'infrastructure',
#    'maintenance',
#    'fully',
#    'fund',
#    'rci']),
#  (True,
#   ['today',
#    'number',
#    '69',
#    'day',
#    'election',
#    '26',
#    'day',
#    '1st',
#    'pres',
#    'debate',
#    '270',
#    'day',
#    'since',
#    'hillary',
#    'clinton',
#    'last',
#    'press',
#    'conf']),
#  (True, ['votetrumpid', 'trump2016']),
#  (False,
#   ['hfa',
#    'meet',
#    'three',
#    'kid',
#    'covered',
#    'child',
#    'health',
#    'insurance',
#    'program',
#    'grown',
#    'lkvz']),
#  (False,
#   ['elizabethbanks',
#    'watch',
#    'friend',
#    'supporting',
#    'hillaryclinton',
#    'demconvention',
#    'strongertogether',
#    'demsinphilly']),
#  (False,
#   ['trump',
#    'think',
#    'giving',
#    'another',
#    'huge',
#    'tax',
#    'cut',
#    'top',
#    'somehow',
#    'help',
#    'working',
#    'family',
#    'give',
#    'break']),
#  (True,
#   ['firstladyin',
#    'going',
#    'roadtripwithblue',
#    'along',
#    'w',
#    '1st',
#    '2d',
#    'grader',
#    'claycounty',
#    'blue',
#    'colt']),
#  (True,
#   ['obama',
#    'clinton',
#    'record',
#    'middle',
#    'class',
#    'labor',
#    'force',
#    'participation',
#    'middle',
#    'class',
#    'job',
#    '900',
#    '000',
#    'income',
#    '1',
#    '656',
#    'demdebate']),
#  (True,
#   ['today',
#    'number',
#    'sc',
#    'debate',
#    '3',
#    'day',
#    'sc',
#    'primary',
#    '10',
#    'day',
#    'nv',
#    'caucus',
#    '13',
#    'day',
#    'gopconvention',
#    '159',
#    'day',
#    'election',
#    '2016',
#    '272',
#    'day']),
#  (True, ['top', '5', 'clinton', 'email', 'lie', 'exposed']),
#  (False,
#   ['sintoniza',
#    'ahora',
#    'lagrand1480',
#    'estar',
#    'hablando',
#    'con',
#    'demetriofloress',
#    'sobre',
#    'la',
#    'crisis',
#    'de',
#    'ni',
#    'buscando',
#    'asilo',
#    'en',
#    'nuestra',
#    'frontera',
#    'sur']),
#  (False,
#   ['met',
#    'intern',
#    'chci',
#    'aspiring',
#    'country',
#    'next',
#    'great',
#    'latino',
#    'leader']),
#  (True,
#   ['govpencein',
#    'today',
#    'mark',
#    '100',
#    'day',
#    'start',
#    'intorchrelay',
#    '3',
#    '200',
#    'mile',
#    'journey',
#    '92',
#    'county',
#    '1zc7t']),
#  (True,
#   ['leaving',
#    'miami',
#    'houston',
#    'oklahoma',
#    'colorado',
#    'miami',
#    'crowd',
#    'wa',
#    'fantastic']),
#  (False,
#   ['call',
#    'sen',
#    'maj',
#    'leader',
#    'mcconnell',
#    'tell',
#    'hold',
#    'vote',
#    'supreme',
#    'court',
#    'nominee',
#    '202',
#    '224',
#    '2541',
#    'callfornine']),
#  (True,
#   ['thanks',
#    'much',
#    '2',
#    'supportive',
#    'friend',
#    'boonecogop',
#    'great',
#    'lincoln',
#    'day',
#    'dinner',
#    'thnx',
#    'delicious',
#    'pie']),
#  (True,
#   ['hillary',
#    'doesnt',
#    'think',
#    'obama',
#    'get',
#    'enough',
#    'credit',
#    'american',
#    'dropped',
#    'labor',
#    'force',
#    'drove']),
#  (True,
#   ['wasnt',
#    'matt',
#    'lauer',
#    'hurt',
#    'hillary',
#    'last',
#    'night',
#    'wa',
#    'dumb',
#    'answer',
#    'email',
#    'veteran',
#    'said',
#    'jail']),
#  (True,
#   ['todayshow',
#    'wife',
#    'melania',
#    'rest',
#    'family',
#    'major',
#    'town',
#    'hall',
#    'hopefully',
#    'fun',
#    'enjoy',
#    '7a']),
#  (True, ['rnc', 'statement', 'vice', 'president', 'biden', 'announcement']),
#  (True,
#   ['watch',
#    'obama',
#    'democrat',
#    'pushed',
#    'pas',
#    'obamacare',
#    'american',
#    'paying',
#    'price']),
#  (True,
#   ['govpencein',
#    'official',
#    'regional',
#    'city',
#    'helping',
#    'boost',
#    'area',
#    'spirit',
#    'courierpress']),
#  (False,
#   ['every',
#    'little',
#    'girl',
#    'dream',
#    'big',
#    'yes',
#    'anything',
#    'want',
#    'even',
#    'president',
#    'tonight',
#    'h']),
#  (True,
#   ['govpencein',
#    'indiana',
#    'agriculture',
#    'administration',
#    'continue',
#    'stand',
#    'hoosier',
#    'farmer']),
#  (False,
#   ['come',
#    'far',
#    'made',
#    'much',
#    'progress',
#    'going',
#    'back',
#    'repjohnlewis',
#    'demsinphilly']),
#  (True,
#   ['indiana',
#    'edc',
#    'salliemae',
#    'investing',
#    '15',
#    '7m',
#    'technology',
#    'talent',
#    'enhance',
#    'customer',
#    'service']),
#  (True,
#   ['realdonaldtrump',
#    'delivers',
#    'address',
#    'restoring',
#    'law',
#    'order',
#    'im',
#    'honored',
#    'stand',
#    'officer',
#    'nm']),
#  (True,
#   ['working',
#    'hard',
#    'get',
#    'sarasota',
#    'fl',
#    'appreciate',
#    'everyone',
#    'braving',
#    'weather']),
#  (True,
#   ['hillary',
#    'defrauded',
#    'america',
#    'secy',
#    'state',
#    'used',
#    'personal',
#    'hedge',
#    'fund',
#    'get',
#    'rich',
#    'corrupt',
#    'dangerous',
#    'dishonest']),
#  (True, ['extremely', 'careless', 'cc', 'hillaryclinton', 'nbcnewsforum']),
#  (True,
#   ['govpencein',
#    '4th',
#    'grader',
#    'longfellow',
#    'mc',
#    'sharp',
#    'really',
#    'enjoyed',
#    'q',
#    'afternoon',
#    'thx',
#    'asking',
#    'great',
#    'q']),
#  (True, ['govpencein', 'thanks', 'memory', 'number', '18', 'thankspeyton']),
#  (True,
#   ['govpencein',
#    'im',
#    '93wibc',
#    'w',
#    'garrisonradio',
#    'talking',
#    'abt',
#    'today',
#    'fy',
#    '15',
#    'closeout',
#    'week',
#    'amazon',
#    'nationalffa',
#    'news',
#    'listen']),
#  (True,
#   ['rga',
#    'indiana',
#    'unemployment',
#    'rate',
#    'fell',
#    '4',
#    '7',
#    'july',
#    'lowest',
#    'point',
#    'since',
#    'november',
#    '2007',
#    'gov',
#    'mike',
#    'penny',
#    'get',
#    'result']),
#  (False,
#   ['im',
#    'headed',
#    'senate',
#    'floor',
#    'pay',
#    'tribute',
#    'alison',
#    'parker',
#    'adam',
#    'ward',
#    'wdbj',
#    'family']),
#  (True,
#   ['lucdwin',
#    'luck',
#    'wa',
#    'rli',
#    'fellow',
#    '1st',
#    'class',
#    'wa',
#    'hired',
#    'full',
#    'time',
#    'staff',
#    'fl',
#    'rnctrailblazer2016']),
#  (False,
#   ['donald',
#    'trump',
#    'became',
#    'republican',
#    'nominee',
#    'chip',
#    'make',
#    'sure',
#    'never',
#    'step',
#    'foot',
#    'oval',
#    'office']),
#  (False,
#   ['trump',
#    'came',
#    'one',
#    'step',
#    'closer',
#    'becoming',
#    'gop',
#    'nominee',
#    'last',
#    'night',
#    'let',
#    'stop']),
#  (False,
#   ['mayaharris',
#    'applaud',
#    'senate',
#    'dems',
#    'strong',
#    'proposal',
#    'help',
#    'family',
#    'fleeing',
#    'violence',
#    'persecution',
#    'central',
#    'america']),
#  (False,
#   ['michigan',
#    'mississippi',
#    'spoken',
#    'say',
#    'ready',
#    'elect',
#    'democrat',
#    'year']),
#  (False,
#   ['let',
#    'celebrate',
#    '73',
#    'straight',
#    'month',
#    'private',
#    'sector',
#    'job',
#    'growth',
#    '5',
#    'unemployment',
#    'le',
#    '10',
#    'uninsured']),
#  (True,
#   ['govpencein',
#    'great',
#    'time',
#    'meeting',
#    'community',
#    'civic',
#    'leader',
#    'zionsville',
#    'rosie',
#    'diner',
#    'lunch']),
#  (False,
#   ['let',
#    'make',
#    'sure',
#    'doesnt',
#    'happen',
#    'ready',
#    'november',
#    'register',
#    'vote']),
#  (True,
#   ['gopconvention',
#    'pambondi',
#    'stage',
#    'next',
#    'gopconvention',
#    'tune',
#    'right',
#    'rncincle',
#    'fn']),
#  (False,
#   ['donald',
#    'trump',
#    'ha',
#    'painted',
#    'dark',
#    'divisive',
#    'picture',
#    'america',
#    '102',
#    'day',
#    'stop',
#    'becoming',
#    'president']),
#  (True,
#   ['crooked',
#    'hillary',
#    'clinton',
#    'spending',
#    'fortune',
#    'ad',
#    'one',
#    'person',
#    'doesnt',
#    'want',
#    'run',
#    'fun']),
#  (True,
#   ['govpencein',
#    'coming',
#    'indystatefair',
#    'sure',
#    'download',
#    '2015',
#    'indystatefair',
#    'app',
#    'arrive',
#    'yrofthefarmer']),
#  (True,
#   ['penny',
#    'authorizes',
#    'national',
#    'guard',
#    'soldier',
#    'carry',
#    'personal',
#    'handgun',
#    'via',
#    'wish',
#    'tv']),
#  (True,
#   ['welcome',
#    'race',
#    'scottwalker',
#    'show',
#    'youre',
#    'ready',
#    '2016',
#    'take',
#    'gop',
#    'straw',
#    'poll']),
#  (False,
#   ['proud',
#    'cosponsor',
#    'dual',
#    'enrollment',
#    'bill',
#    'help',
#    'h',
#    'student',
#    'earn',
#    'college',
#    'credit',
#    'cut',
#    'cost',
#    'college',
#    'diploma']),
#  (True,
#   ['got',
#    'lot',
#    'business',
#    'done',
#    'russian',
#    'hillaryclinton',
#    'demdebate']),
#  (True,
#   ['leadership',
#    'obama',
#    'clinton',
#    'american',
#    'experienced',
#    'attack',
#    'home',
#    'victory',
#    'abroad',
#    'time',
#    'change',
#    'playbook']),
#  (False, ['actonclimate']),
#  (False,
#   ['firstfiveyears',
#    'sen',
#    'timkaine',
#    'expanding',
#    'access',
#    'pre',
#    'k',
#    'smart',
#    'investment',
#    'earlyed',
#    'investinus']),
#  (False,
#   ['member',
#    'side',
#    'support',
#    'balanced',
#    'approach',
#    'sequester',
#    'relief',
#    'b',
#    'defense',
#    'non',
#    'defense',
#    'budget',
#    'time']),
#  (False,
#   ['hillary',
#    'esp',
#    'seremos',
#    'compa',
#    'eros',
#    'de',
#    'alma',
#    'en',
#    'esta',
#    'gran',
#    'lucha',
#    'por',
#    'venir',
#    'dijo',
#    'timkaine',
#    'sobre',
#    'hillaryclinton']),
#  (True,
#   ['govpencein',
#    'clinic',
#    'first',
#    'kind',
#    'indiana',
#    'veteran',
#    'benefit',
#    'new',
#    'opportunity',
#    'care']),
#  (False,
#   ['driving',
#    'fort',
#    'pickett',
#    'meet',
#    'w',
#    'local',
#    'official',
#    'tour',
#    'site',
#    'future',
#    'embassy',
#    'security',
#    'training',
#    'center']),
#  (True, ['guide', 'republican', 'national', 'convention']),
#  (True,
#   ['median',
#    'household',
#    'income',
#    'middle',
#    'class',
#    'since',
#    'obama',
#    'took',
#    'office',
#    'go',
#    'clinton']),
#  (False,
#   ['ive',
#    'never',
#    'heard',
#    'american',
#    'leader',
#    'claiming',
#    'need',
#    'democracy',
#    'friend',
#    'hillary']),
#  (True,
#   ['must',
#    'registered',
#    'republican',
#    'february',
#    '16th',
#    'vote',
#    'trump',
#    'florida',
#    'primary']),
#  (False,
#   ['apprenticeship',
#    'program',
#    'critical',
#    'growing',
#    'nation',
#    'talented',
#    'workforce',
#    'read',
#    'bill']),
#  (False,
#   ['heartfelt',
#    'congratulation',
#    'sri',
#    'lankan',
#    'people',
#    'successful',
#    'election',
#    'historic',
#    'step',
#    'toward',
#    'democratic',
#    'prosperous',
#    'sri',
#    'lanka']),
#  (False,
#   ['campaign',
#    'need',
#    'american',
#    'people',
#    'addressing',
#    'serious',
#    'crisis',
#    'face',
#    'berniesanders']),
#  (True,
#   ['teampence',
#    'region',
#    '8',
#    'field',
#    'office',
#    'officially',
#    'open',
#    'startyourenginestour']),
#  (True,
#   ['sen',
#    'lindsey',
#    'graham',
#    'embarrassed',
#    'failed',
#    'run',
#    'president',
#    'embarrasses',
#    'endorsement',
#    'bush']),
#  (True,
#   ['ffa',
#    'national',
#    'convention',
#    'commits',
#    'indianapolis',
#    'next',
#    '9',
#    'year']),
#  (True,
#   ['govpencein',
#    'pleased',
#    'see',
#    'sb',
#    '165',
#    'codifying',
#    'hip',
#    '2',
#    '0',
#    'pas',
#    'health',
#    'provider',
#    'service',
#    'committee',
#    'unanimously',
#    'govagenda',
#    'inlegis']),
#  (True,
#   ['crooked',
#    'hillary',
#    'want',
#    'radical',
#    '500',
#    'increase',
#    'syrian',
#    'refugee',
#    'allow',
#    'time',
#    'get',
#    'smart',
#    'protect',
#    'america']),
#  (False,
#   ['proud',
#    'ctemonth',
#    'passed',
#    'senate',
#    'unanimously',
#    'cte',
#    'vital',
#    'workforce',
#    'future',
#    'read']),
#  (True,
#   ['indiana',
#    'kid',
#    'outperformed',
#    'national',
#    'average',
#    'every',
#    'major',
#    'category',
#    'nation',
#    'report',
#    'card']),
#  (False,
#   ['heading',
#    'senate',
#    'floor',
#    'soon',
#    'discus',
#    'danger',
#    'obstructing',
#    'ambassador',
#    'nominee',
#    'weakens',
#    'leadership',
#    'throughout',
#    'world']),
#  (False,
#   ['ted',
#    'cruz',
#    'rand',
#    'paul',
#    'flat',
#    'tax',
#    'plan',
#    'would',
#    'either',
#    'raise',
#    'tax',
#    'blow',
#    'deficit',
#    'omgop',
#    'gopdebate']),
#  (True,
#   ['kasich',
#    'ha',
#    'helped',
#    'decimate',
#    'coal',
#    'steel',
#    'industry',
#    'ohio',
#    'bring',
#    'back',
#    'makeamericagreatagain']),
#  (True,
#   ['govpencein',
#    'great',
#    'turnout',
#    'h',
#    'kent',
#    'weldon',
#    'conference',
#    'higher',
#    'education',
#    'afternoon',
#    'higheredin']),
#  (True,
#   ['realdonaldtrump',
#    'hillaryclinton',
#    'channel',
#    'john',
#    'kerry',
#    'trade',
#    'wa',
#    'bad',
#    'trade',
#    'deal',
#    'wa',
#    'tpp',
#    'debates2']),
#  (True,
#   ['frmr',
#    'va',
#    'gov',
#    'tim',
#    'kaine',
#    'hillary',
#    'clinton',
#    'vp',
#    'short',
#    'list',
#    'accepted',
#    '160k',
#    'worth',
#    'clothes',
#    'vacation',
#    'gift']),
#  (False, ['lgbt', 'dems', 'democrat', 'made', 'history', 'week']),
#  (False,
#   ['let',
#    'beat',
#    'back',
#    'assault',
#    'voting',
#    'right',
#    'blast',
#    'jim',
#    'crow',
#    'past',
#    'must',
#    'stopped',
#    'expand',
#    'voting',
#    'right',
#    'instead']),
#  (True,
#   ['reince',
#    'today',
#    'gop',
#    'commemorates',
#    '53rd',
#    'anniversary',
#    'dr',
#    'martin',
#    'luther',
#    'king',
#    'jr',
#    'dream',
#    'speech']),
#  (False,
#   ['could',
#    'prouder',
#    'leader',
#    'nominated',
#    'take',
#    'place',
#    'potus',
#    'hillary']),
#  (True,
#   ['stopped',
#    'goody',
#    'family',
#    'restaurant',
#    'lunch',
#    'w',
#    'local',
#    'union',
#    'leader',
#    'heading',
#    'youngstown',
#    'americafirst']),
#  (False,
#   ['koreanamericanday',
#    'honor',
#    'impact',
#    'korean',
#    'american',
#    'community',
#    'across',
#    'virginia',
#    'america']),
#  (True,
#   ['2016',
#    'gopconvention',
#    'store',
#    'q',
#    'officially',
#    'open',
#    'shop',
#    'rncincle',
#    'gear']),
#  (False,
#   ['rtdnews',
#    'new',
#    'foreign',
#    'affair',
#    'security',
#    'training',
#    'center',
#    'mean',
#    'va']),
#  (True,
#   ['brandthershman',
#    'indiana',
#    'income',
#    'growth',
#    'outpaces',
#    'u',
#    'last',
#    '5',
#    '6',
#    'year',
#    'astatethatworks']),
#  (True,
#   ['govpencein',
#    'joined',
#    'subaru',
#    'usa',
#    'announced',
#    'plan',
#    'significantly',
#    'expand',
#    'creating',
#    '1',
#    '204',
#    'job',
#    '2017']),
#  (True,
#   ['tax',
#    'terrorism',
#    'obama',
#    'ignoring',
#    'voter',
#    'retweet',
#    'demand',
#    'listen']),
#  (False, ['wearedemocrats', 'demdebate']),
#  (True, ['stage', 'podium', 'set', 'gopdebate']),
#  (False,
#   ['unlike',
#    'plan',
#    'immigrant',
#    'democrat',
#    'focus',
#    'important',
#    'family',
#    'economy',
#    'cnndebate']),
#  (True,
#   ['way',
#    'dayton',
#    'oh',
#    'onto',
#    'cambridge',
#    'oh',
#    'talk',
#    'job',
#    'security',
#    'late',
#    'rsvp',
#    'wi',
#    'thu']),
#  (False,
#   ['vote',
#    'ca',
#    'mt',
#    'nj',
#    'nm',
#    'nd',
#    'sd',
#    'today',
#    'day',
#    'make',
#    'voice',
#    'heard']),
#  (False, ['watch', 'glass', 'ceiling', 'coming', 'womensequalityday']),
#  (True,
#   ['indgop',
#    'penny',
#    'outraised',
#    'gregg',
#    'year',
#    'end',
#    'fundraising',
#    'report',
#    'read']),
#  (False,
#   ['hillaryclinton', 'many', 'democrat', 'ballot', 'agree', 'nbcnewsforum']),
#  (False,
#   ['dncwomen',
#    'mike',
#    'huckabee',
#    'want',
#    'amend',
#    'constitution',
#    'overturn',
#    'roe',
#    'v',
#    'wade',
#    'voting',
#    'democrat',
#    'roe43']),
#  (False, ['iowademocrats', '20', 'minute', 'go', 'demdebate']),
#  (False,
#   ['incredibly',
#    'saddened',
#    'hear',
#    'beau',
#    'biden',
#    'passing',
#    'wa',
#    'life',
#    'dedicated',
#    'serving',
#    'others',
#    'heart',
#    'go',
#    'biden',
#    'family']),
#  (False,
#   ['en',
#    'mi',
#    'op',
#    'ed',
#    'en',
#    'el',
#    'pais',
#    'recuerdo',
#    'mi',
#    'visita',
#    'honduras',
#    'mi',
#    'servicio',
#    'en',
#    'ese',
#    'mismo',
#    'pais',
#    'con',
#    'jesuitasesp',
#    'hace',
#    '35']),
#  (True, ['onthisday', '1863']),
#  (False,
#   ['donald',
#    'trump',
#    'really',
#    'good',
#    'spending',
#    'people',
#    'money',
#    'legal',
#    'settlement',
#    'payoff',
#    'portrait']),
#  (True,
#   ['gopconvention',
#    'backstage',
#    'gopconvention',
#    'rncincle',
#    'digital',
#    'loft',
#    'kimberlinbrown']),
#  (True,
#   ['breaking',
#    'news',
#    'bernie',
#    'sander',
#    'cave',
#    'hillary',
#    'clinton',
#    'rigged',
#    'system']),
#  (True,
#   ['cory',
#    'booker',
#    'future',
#    'democratic',
#    'party',
#    'future',
#    'know',
#    'cory',
#    'know']),
#  (False, ['one', 'hour', 'go', 'watch', 'demdebate', 'cbsnews']),
#  (False,
#   ['appreciate',
#    'jackandjillinc',
#    'work',
#    'help',
#    'family',
#    'like',
#    'alexandria',
#    'prince',
#    'william',
#    'visited',
#    'today']),
#  (True,
#   ['govpencein',
#    'gather',
#    'ims',
#    'today',
#    'pause',
#    'thank',
#    'hoosier',
#    'veteran',
#    'service',
#    'member',
#    'indy500']),
#  (True,
#   ['icymi',
#    '76',
#    'debate',
#    'watch',
#    'party',
#    'organized',
#    'hispanic',
#    'community',
#    'across',
#    'country']),
#  (False,
#   ['naturbanleague',
#    'need',
#    'look',
#    'injustice',
#    'square',
#    'face',
#    'fight',
#    'timkaine',
#    'saveourcities']),
#  (False,
#   ['commander',
#    'chief',
#    'insult',
#    'deride',
#    'general',
#    'retired',
#    'otherwise',
#    'really',
#    'go',
#    'without',
#    'saying']),
#  (False,
#   ['proud',
#    'american',
#    'promise',
#    'america',
#    'big',
#    'enough',
#    'u',
#    'hillaryclinton']),
#  (False,
#   ['four',
#    'gold',
#    'medal',
#    'counting',
#    'today',
#    'serenawilliams',
#    'hit',
#    'court',
#    'rio',
#    'add',
#    'collection']),
#  (True, ['thank', 'kentucky', 'trump2016', 'supersaturday']),
#  (False, ['ready', 'sotu', 'join', 'u', 'tuesday', '9', 'pm', 'et']),
#  (True, ['rncresearch', 'bidenrules', '2']),
#  (True,
#   ['govpencein',
#    'bipartisan',
#    'work',
#    'done',
#    'ensure',
#    'teacher',
#    'compensation',
#    'bonus',
#    'affected',
#    'latest',
#    'istep',
#    'score',
#    'wow']),
#  (False,
#   ['decide',
#    'whether',
#    'work',
#    'together',
#    'rise',
#    'together',
#    'hillary',
#    'clinton',
#    'demsinphilly']),
#  (True,
#   ['melindaross123',
#    'foxnews',
#    'realdonaldtrump',
#    'isnt',
#    'anything',
#    'donald',
#    'trump',
#    'say',
#    'dont',
#    'agree',
#    'go',
#    'trump']),
#  (False,
#   ['two',
#    'day',
#    'go',
#    'next',
#    'democratic',
#    'debate',
#    'tune',
#    'saturday',
#    '9',
#    'pm',
#    'cbsnews']),
#  (False, ['ridiculous', 'ha', 'never', 'female', 'president']),
#  (True,
#   ['crack',
#    'firewall',
#    'clinton',
#    'campaign',
#    'already',
#    'trying',
#    'lower',
#    'expectation',
#    'nv']),
#  (True, ['stophillary', 'take', 'survey', 'tell', 'u']),
#  (True,
#   ['bernie',
#    'ha',
#    'totally',
#    'given',
#    'fight',
#    'people',
#    'welcome',
#    'voter',
#    'want',
#    'better',
#    'future',
#    'worker']),
#  (False, ['sunday', 'inspiration', 'next', 'vice', 'president']),
#  (False,
#   ['wearedemocrats',
#    'ready',
#    'elect',
#    '45th',
#    'president',
#    'united',
#    'state',
#    'demdebate']),
#  (True,
#   ['judge',
#    'trump',
#    'university',
#    'civil',
#    'case',
#    'gonzalo',
#    'curiel',
#    'san',
#    'diego',
#    'unfair',
#    'obama',
#    'pick',
#    'totally',
#    'biased',
#    'hate',
#    'trump']),
#  (True,
#   ['stay', 'tuned', 'live', 'tweet', 'indgop', 'spring', 'dinner', 'address']),
#  (False, ['man', 'people']),
#  (False,
#   ['chatted',
#    'w',
#    'bright',
#    'senior',
#    'strasburghs',
#    'morning',
#    'skype',
#    'covered',
#    'lot',
#    'great',
#    'topic',
#    'shencovaschools']),
#  (True, ['interviewed', 'morning', 'joe', '6', '15', 'enjoy']),
#  (True,
#   ['great',
#    'endorsement',
#    'support',
#    'paul',
#    'ryan',
#    'working',
#    'hard',
#    'make',
#    'america',
#    'great']),
#  (False,
#   ['come',
#    'make',
#    'clear',
#    'possible',
#    'endorsing',
#    'hillary',
#    'clinton',
#    'berniesanders',
#    'new',
#    'hampshire']),
#  (False,
#   ['lorellapraeli',
#    'thedream',
#    'u',
#    'continues',
#    'build',
#    'ladder',
#    'opportunity',
#    'providing',
#    'scholarship',
#    'dreamer',
#    'huge',
#    'milestone']),
#  (True,
#   ['leaving',
#    'one',
#    'night',
#    'trip',
#    'scotland',
#    'order',
#    'grand',
#    'opening',
#    'great',
#    'turnberry',
#    'resort',
#    'back',
#    'sat',
#    'night']),
#  (True, ['thank', 'much', 'earnest', 'must', 'great', 'person']),
#  (True,
#   ['thank',
#    'teacher',
#    'across',
#    'america',
#    'become',
#    'potus',
#    'make',
#    'education',
#    'far',
#    'important',
#    'component',
#    'life']),
#  (False, ['agree', 'president', 'obama']),
#  (False,
#   ['honored',
#    'speak',
#    'hrc',
#    '15th',
#    'annual',
#    'leadership',
#    'summit',
#    'morning',
#    'equalrights',
#    'fighting',
#    'discrimination',
#    'celebratehrc']),
#  (True,
#   ['hillary',
#    'clinton',
#    'take',
#    'cash',
#    'mr',
#    'marijuana',
#    'inconsistent',
#    'position',
#    'legalization',
#    'spotlight']),
#  (True, ['false']),
#  (False,
#   ['potus',
#    'said',
#    'first',
#    'mosquevisit',
#    'founding',
#    'father',
#    'like',
#    'thomas',
#    'jefferson',
#    'made',
#    'religious',
#    'freedom',
#    'foundation',
#    'nation']),
#  (False,
#   ['democrat',
#    'fighting',
#    'disenfranchised',
#    'citizen',
#    'make',
#    'voice',
#    'heard']),
#  (True,
#   ['everything', 'need', 'know', 'hoosier', 'state', 'primary', 'inprimary']),
#  (False,
#   ['take',
#    'minute',
#    'check',
#    'call',
#    '1',
#    '800',
#    '318',
#    '2596',
#    'learn',
#    'way',
#    'getcovered']),
#  (False,
#   ['emocionado',
#    'por',
#    'hablar',
#    'con',
#    'lorimontenegro',
#    'la',
#    '7am',
#    'ante',
#    'del',
#    'discurso',
#    'del',
#    'papafrancisco',
#    'al',
#    'congreso',
#    'sinton',
#    'zate',
#    'telemundonews']),
#  (False,
#   ['sintoniza',
#    'ahora',
#    'selecta1320',
#    'para',
#    'escuchar',
#    'nuestra',
#    'discusion',
#    'sobre',
#    'la',
#    'crisis',
#    'de',
#    'los',
#    'ninos',
#    'en',
#    'la',
#    'frontera']),
#  (True, ['together', 'better', 'retweet', 'tell', 'u', 'start']),
#  (False,
#   ['productive',
#    'worker',
#    'world',
#    'need',
#    'give',
#    'people',
#    'chance',
#    'succeed']),
#  (True,
#   ['govpencein',
#    'proud',
#    'announce',
#    'today',
#    'creation',
#    'governor',
#    'task',
#    'force',
#    'drug',
#    'enforcement',
#    'treatment',
#    'prevention']),
#  (True,
#   ['indiana2016',
#    'april',
#    '4',
#    '1968',
#    'robert',
#    'f',
#    'kennedy',
#    'gave',
#    'famous',
#    'speech',
#    'peace',
#    'watch']),
#  (True,
#   ['clinton',
#    'ha',
#    'watched',
#    'sickening',
#    'slow',
#    'motion',
#    'sequel',
#    'poll',
#    'number',
#    'cratered',
#    'ia']),
#  (False,
#   ['estas',
#    'son',
#    'la',
#    'promesas',
#    'de',
#    'trump',
#    'podr',
#    'ser',
#    'su',
#    'presidencia']),
#  (False,
#   ['concern',
#    'going',
#    'look',
#    'working',
#    'family',
#    'side',
#    'got',
#    'nothing',
#    'offer',
#    'potus']),
#  (True,
#   ['good',
#    'morning',
#    'america',
#    'thank',
#    'support',
#    'latest',
#    'drudge',
#    'poll']),
#  (True,
#   ['govpencein',
#    'walking',
#    'around',
#    'firstladyin',
#    'meet',
#    'fellow',
#    'participant',
#    'today',
#    '500festival',
#    'parade']),
#  (False,
#   ['week',
#    'excited',
#    'celebrate',
#    'vademocrats',
#    'hillaryclinton',
#    'tonight',
#    'jefferson',
#    'jackson',
#    'dinner',
#    'fairfax']),
#  (False,
#   ['fight',
#    'ha',
#    'begun',
#    'youre',
#    'ready',
#    'elect',
#    'hillary',
#    'clinton',
#    'next',
#    'president',
#    'united',
#    'state']),
#  (True, ['realdonaldtrump', 'ha', 'got', 'back', 'williebosshog', 'rncincle']),
#  (True,
#   ['govpencein',
#    'proud',
#    'ceremonially',
#    'sign',
#    'hea',
#    '1456',
#    'sea',
#    '298',
#    '122fighterwing',
#    'afternoon',
#    'ft',
#    'wayne']),
#  (False,
#   ['whitehouse',
#    '12',
#    '30pm',
#    'et',
#    'watch',
#    'potus',
#    'deliver',
#    'statement',
#    'economy']),
#  (False,
#   ['right',
#    'vote',
#    'still',
#    'powerful',
#    'nonviolent',
#    'tool',
#    'transformation',
#    'repjohnlewis']),
#  (False,
#   ['dncwomen',
#    'donald',
#    'trump',
#    'misogynist',
#    'racist',
#    'bigot',
#    'voting',
#    'arent',
#    'either',
#    'b8v4vvb']),
#  (True,
#   ['pres',
#    'obama',
#    'american',
#    'confidence',
#    'fed',
#    'govt',
#    'protect',
#    'terrorism',
#    'ha',
#    'plummeted',
#    'new',
#    'low']),
#  (True, ['throwbackthursday', 'trump2016']),
#  (False,
#   ['trump',
#    'nuanced',
#    'plan',
#    'combatting',
#    'complicated',
#    'topic',
#    'isi',
#    'bomb',
#    'sh',
#    'betterthanthis']),
#  (False, ['exclusive', 'weve', 'located', 'donald', 'trump', 'tax', 'return']),
#  (True,
#   ['govpencein',
#    'appreciated',
#    'hearing',
#    'local',
#    'farmer',
#    'seeing',
#    'first',
#    'hand',
#    'extent',
#    'damage',
#    'crop',
#    'sustained',
#    'june']),
#  (True,
#   ['50',
#    'woman',
#    'interviewed',
#    'nytimes',
#    'yet',
#    'wrote',
#    '6',
#    'many',
#    'positive',
#    'statement']),
#  (False,
#   ['let',
#    'make',
#    'sure',
#    'realdonaldtrump',
#    'never',
#    'ha',
#    'chance',
#    'bankrupt',
#    'america',
#    'way',
#    'bankrupted',
#    'business']),
#  (True, ['getting', 'ready', 'blastonthebridge2016', 'fisher']),
#  (False,
#   ['happybirthdayyourmajesty',
#    'tbt',
#    'queen',
#    'elizabeth',
#    'ii',
#    'virginia',
#    'visit',
#    '400th',
#    'birthday',
#    'jamestown']),
#  (False, ['youll', 'watching', 'last', 'sotu', 'tomorrow', 'night', 'rsvp']),
#  (True,
#   ['join',
#    'monday',
#    'columbus',
#    'ohio',
#    'harrisburg',
#    'pennsylvania',
#    'maga',
#    '3pm',
#    'oh',
#    '7pm',
#    'pa']),
#  (False,
#   ['nw',
#    'ha',
#    'issued',
#    'severe',
#    'thunderstorm',
#    'warning',
#    'southeast',
#    'virginia',
#    'including',
#    'chesapeake',
#    'norfolk',
#    'va',
#    'beach',
#    'stay',
#    'safe',
#    'everyone']),
#  (False, ['slamming', 'door', 'immigrant', 'opposite', 'nation']),
#  (False,
#   ['obligation',
#    'protect',
#    'open',
#    'internet',
#    'defend',
#    'net',
#    'neutrality']),
#  (True, ['join', 'zionsville', 'indiana', 'today', 'rally']),
#  (True,
#   ['govpencein',
#    'moment',
#    'admin',
#    'learned',
#    'announcement',
#    'workoneworks',
#    'reached',
#    'employee',
#    'offer',
#    'job',
#    'seeking',
#    'traini']),
#  (False,
#   ['smashingwalnuts',
#    'thank',
#    'hard',
#    'work',
#    'raise',
#    'awareness',
#    'issue',
#    'ill',
#    'continue']),
#  (False,
#   ['hillary', 'clinton', 'working', 'mom', 'never', 'stop', 'fighting']),
#  (False,
#   ['happen',
#    'common',
#    'sense',
#    'reform',
#    'reduce',
#    'gun',
#    'violence',
#    'america',
#    'demdebate']),
#  (True,
#   ['keksec',
#    'org',
#    'realdonaldtrump',
#    'policy',
#    'make',
#    'state',
#    'country',
#    'great',
#    'makeamericagreatagain']),
#  (False,
#   ['nationaldonutday',
#    'surprise',
#    'richmond',
#    'rvadonuts',
#    'wa',
#    'named',
#    'one',
#    'country',
#    'best']),
#  (True, ['thank', 'georgia', 'americafirst', 'makeamericagreatagain']),
#  (True,
#   ['edatpost',
#    'warren',
#    'speaks',
#    'sander',
#    'supporter',
#    'chant',
#    'loudly',
#    'rafter']),
#  (False,
#   ['modemparty',
#    'tedcruz',
#    'say',
#    'gopdebate',
#    'candidate',
#    'would',
#    'better',
#    'berniesanders',
#    'hillaryclinton']),
#  (True,
#   ['crooked',
#    'hillary',
#    'clinton',
#    'wa',
#    'loyal',
#    'person',
#    'rigged',
#    'system',
#    'pushed',
#    'top',
#    'dws',
#    'bad',
#    'bernie',
#    'flamed']),
#  (False,
#   ['potus',
#    'memorial',
#    'day',
#    'hope',
#    'youll',
#    'join',
#    'act',
#    'remembrance',
#    'debt',
#    'owe',
#    'fallen',
#    'hero',
#    'one',
#    'never',
#    'truly',
#    'rep']),
#  (True,
#   ['govpencein',
#    'pleased',
#    'sign',
#    'hea',
#    '1267',
#    'allow',
#    'farm',
#    'fork',
#    'industry',
#    'continue',
#    'grow',
#    'w',
#    'food',
#    'safety',
#    'framework',
#    'place']),
#  (False,
#   ['last',
#    'thing',
#    'need',
#    'president',
#    'brings',
#    'name',
#    'calling',
#    'temper',
#    'tantrum',
#    'washington']),
#  (True,
#   ['look',
#    'forward',
#    'introducing',
#    'governor',
#    'mike',
#    'penny',
#    'ha',
#    'done',
#    'spectacular',
#    'job',
#    'great',
#    'state',
#    'indiana',
#    'first',
#    'choice',
#    'start']),
#  (False,
#   ['watch',
#    'summary',
#    'yesterday',
#    'bipartisan',
#    'forum',
#    'sea',
#    'level',
#    'rise',
#    'norfolk']),
#  (False,
#   ['today',
#    'hundred',
#    'concerned',
#    'texan',
#    'embarking',
#    '3',
#    'day',
#    'pilgrimage',
#    'governor',
#    'mansion',
#    'show',
#    'support',
#    'daca',
#    'dapa',
#    'jg']),
#  (False,
#   ['cant',
#    'promise',
#    'well',
#    'win',
#    'every',
#    'fight',
#    'first',
#    'try',
#    'ill',
#    'never',
#    'stop',
#    'fighting',
#    'hillary']),
#  (False,
#   ['paulbegala',
#    'clintinfdn',
#    '200k',
#    'people',
#    'hiv',
#    'aid',
#    'poor',
#    'country',
#    'got',
#    'lifesaving',
#    'anti',
#    'retroviral',
#    'med',
#    'clintonfdn']),
#  (True,
#   ['tremendous',
#    'momentum',
#    'right',
#    'let',
#    'moment',
#    'join',
#    'u',
#    'tomorrow',
#    'rally',
#    'leetonia',
#    'oh']),
#  (True,
#   ['congrats',
#    'cavs',
#    'team',
#    'first',
#    'winner',
#    'cleveland',
#    'produce',
#    'summer']),
#  (False,
#   ['caroldwoodward',
#    'chippokes',
#    'vastateparks',
#    'along',
#    'james',
#    'river',
#    'findyourpark',
#    'vaisfornpslovers',
#    'nps100',
#    'timkaine']),
#  (True, ['score', 'another', 'indy', 'tech', 'sector', 'iib']),
#  (False,
#   ['hosting',
#    'citizenday',
#    'norfolk',
#    'joining',
#    'chesapeakebay',
#    'foundation',
#    'help',
#    'oyster',
#    'restoration',
#    'lafayette',
#    'river']),
#  (True,
#   ['word',
#    'come',
#    'mind',
#    'think',
#    'hillaryclinton',
#    'deleting',
#    'nearly',
#    '18k',
#    'email',
#    'obstruction']),
#  (False,
#   ['70',
#    'yr',
#    'ago',
#    'today',
#    '6',
#    'servicemembers',
#    'raised',
#    'u',
#    'flag',
#    'japanese',
#    'island',
#    'iwo',
#    'jima',
#    'proud',
#    'memorial',
#    'va']),
#  (True,
#   ['transparent',
#    'admin',
#    'ever',
#    'state',
#    'dept',
#    'burying',
#    'latest',
#    'court',
#    'ordered',
#    'release',
#    'clinton',
#    'email',
#    'nye']),
#  (False,
#   ['trump',
#    'actively',
#    'engaging',
#    'type',
#    'washington',
#    'quid',
#    'pro',
#    'quo',
#    'american',
#    'sick']),
#  (False,
#   ['honored',
#    'participate',
#    'wreath',
#    'laying',
#    'ceremony',
#    '239th',
#    'birthday',
#    'usmc',
#    'arlington',
#    'semper',
#    'fi']),
#  (True,
#   ['govpencein',
#    'happy',
#    'new',
#    'year',
#    'eve',
#    'indiana',
#    'ring',
#    '2016',
#    'friend',
#    'family',
#    'safe',
#    'celebration']),
#  (False, ['america', 'beacon', 'hope', 'world', 'terrorist', 'change']),
#  (False, ['iowademocrats', 'excited', 'first', 'demdebate', 'tonight']),
#  (True,
#   ['thank',
#    'clemson',
#    'south',
#    'carolina',
#    'makeamericagreatagain',
#    'scprimary']),
#  (True, ['total', '155', 'delegate', 'stake', 'today']),
#  (True,
#   ['govpencein',
#    'good',
#    'fun',
#    'gov',
#    'onetoughnerd',
#    'thx',
#    'bearing',
#    'w',
#    'bearindiana']),
#  (True,
#   ['least',
#    '3',
#    'email',
#    'belonging',
#    'hillary',
#    'clinton',
#    'related',
#    'set',
#    'secret',
#    'server',
#    'never',
#    'turned']),
#  (False,
#   ['catch',
#    'full',
#    'interview',
#    'tonight',
#    'newschannel8',
#    '8',
#    '30pm',
#    '11',
#    '30pm']),
#  (True, ['thanks', 'great', 'turnout', 'tonight', 'mesa', 'arizona', 'maga']),
#  (True,
#   ['source',
#    'say',
#    'biden',
#    'ha',
#    'obama',
#    'blessing',
#    'challenge',
#    'hillary',
#    'nomination']),
#  (False,
#   ['dominiclowell',
#    'proud',
#    'many',
#    'student',
# ...
#    'dealer',
#    'halt',
#    'sale',
#    'background',
#    'check',
#    'completed']),
#  (False,
#   ['know',
#    'donald',
#    'trump',
#    'say',
#    'offensive',
#    'thing',
#    'woman',
#    'say',
#    'policy',
#    'benefit',
#    'woman']),
#  (True,
#   ['govpencein',
#    'good',
#    'food',
#    'fellowship',
#    'bonfire',
#    'get',
#    'started',
#    'tonight',
#    'today',
#    'weather',
#    'going',
#    'need',
#    'c']),
#  (False, []),
#  (True,
#   ['told',
#    'country',
#    'totally',
#    'lost',
#    'control',
#    'illegal',
#    'immigration',
#    'even',
#    'criminal']),
#  (True, ['behind', 'scene', 'today', 'gopdebate', 'detroit']),
#  (False, ['looking', 'forward', 'tonight', 'gopdebate', 'u']),
#  (False,
#   ['list',
#    'great',
#    'vasciencefest',
#    'event',
#    'throughout',
#    'state',
#    'beginning',
#    'sat',
#    'click']),
#  (True,
#   ['exclusive',
#    'john',
#    'kasich',
#    'interview',
#    'w',
#    'rnc',
#    'part',
#    'focus',
#    'candidate',
#    'series']),
#  (False,
#   ['collegedems',
#    '50',
#    'day',
#    'left',
#    'college',
#    'dems',
#    'get',
#    'done',
#    'read',
#    'president',
#    'marvmcmoore',
#    'medium']),
#  (True,
#   ['many',
#    'year',
#    'inner',
#    'city',
#    'left',
#    'behind',
#    'going',
#    'deliver',
#    'job',
#    'safety',
#    'protection',
#    'need']),
#  (True,
#   ['gopconvention',
#    'headliner',
#    'speaker',
#    'day',
#    '2',
#    'gopconvention',
#    'click',
#    'full',
#    'rncincle',
#    'coverage']),
#  (True,
#   ['katesapple',
#    '110th',
#    'door',
#    'hillary',
#    'sent',
#    '110',
#    'classified',
#    'email',
#    'prefer',
#    'knock',
#    'door',
#    'nhpolitics',
#    'leadright2016',
#    'hko']),
#  (False,
#   ['donald',
#    'trump',
#    'unqualified',
#    'president',
#    'every',
#    'way',
#    'role',
#    'model',
#    'want',
#    'child']),
#  (True,
#   ['hondaindiana',
#    'excited',
#    'govpencein',
#    'bit',
#    'join',
#    'u',
#    'exciting',
#    'announcement',
#    'stay',
#    'tuned']),
#  (True,
#   ['welcome',
#    'race',
#    'governorpataki',
#    'take',
#    'straw',
#    'poll',
#    'show',
#    'youre',
#    'ready',
#    '2016']),
#  (True,
#   ['govpencein',
#    'sb',
#    '67',
#    'local',
#    'road',
#    'funding',
#    'bill',
#    'authored',
#    'sen',
#    'brandthershman',
#    'pass',
#    'senate',
#    'tax',
#    'fiscal',
#    'policy',
#    'committee',
#    'unanim']),
#  (True,
#   ['crooked',
#    'hillary',
#    'clinton',
#    'got',
#    'brexit',
#    'wrong',
#    'said',
#    'leave',
#    'win',
#    'ha',
#    'sense',
#    'market',
#    'bad',
#    'judgement',
#    'question',
#    'time']),
#  (False,
#   ['dncyouthcouncil',
#    'tl',
#    'dr',
#    'obamacare',
#    'worth',
#    'celebrating',
#    'protecting',
#    'youre',
#    'voting',
#    'democrat',
#    '2016',
#    'clm7uye']),
#  (True,
#   ['democrat',
#    'party',
#    'show',
#    'depleted',
#    'rusty',
#    'political',
#    'infrastructure',
#    'dnc']),
#  (True, ['happy', 'halloween']),
#  (True,
#   ['overheard',
#    'demconvention',
#    'new',
#    'hillaryclinton',
#    'chant',
#    'demsinphilly',
#    'enoughclinton']),
#  (True, ['let', 'go', 'pennsylvania', 'votetrump']),
#  (False,
#   ['texasinafrica',
#    'hillaryclinton',
#    'hbcu',
#    'plan',
#    'really',
#    'smart',
#    'address',
#    'many',
#    'critical',
#    'issue',
#    'around',
#    'access',
#    'debt',
#    'im',
#    'impressed',
#    'htt']),
#  (True,
#   ['think',
#    'hillary',
#    'clinton',
#    'ha',
#    'plan',
#    'defeat',
#    'islamic',
#    'extremism']),
#  (False, ['one', 'secretary', 'state', 'another', 'demsinphilly']),
#  (False,
#   ['woman',
#    'access',
#    'contraception',
#    'denied',
#    'pharmacy',
#    'counter',
#    'ha',
#    'made',
#    'decision',
#    'doctor']),
#  (False,
#   ['donald',
#    'trump',
#    'presumptive',
#    'gop',
#    'nominee',
#    'chip',
#    'agree',
#    'cant',
#    'let',
#    'become',
#    'president']),
#  (False, ['democrat', 'believe', 'agree', 'president', 'obama']),
#  (False,
#   ['take',
#    'donald',
#    'trump',
#    'pose',
#    'unprecedented',
#    'risk',
#    'country',
#    'today',
#    'daily',
#    'press']),
#  (False,
#   ['many',
#    'ppfa',
#    'advocate',
#    'hill',
#    'today',
#    'thank',
#    'supporting',
#    'teachsafe',
#    'relationship',
#    'act']),
#  (True,
#   ['gopconvention',
#    'virginiafoxx',
#    'stepped',
#    'stage',
#    'digital',
#    'loft',
#    'gopconvention',
#    'rncincle',
#    'gutoov']),
#  (False,
#   ['great',
#    'back',
#    'philippine',
#    'cultural',
#    'center',
#    'virginia',
#    'beach',
#    'friend',
#    'repbobbyscott']),
#  (True,
#   ['dont',
#    'think',
#    'voter',
#    'forget',
#    'rigged',
#    'system',
#    'allowed',
#    'crooked',
#    'hillary',
#    'get',
#    'away',
#    'murder',
#    'come',
#    'november',
#    '8']),
#  (True,
#   ['hillary',
#    'clinton',
#    'short',
#    'speech',
#    'pandering',
#    'worst',
#    'instinct',
#    'society',
#    'ashamed']),
#  (True,
#   ['cruz',
#    'voter',
#    'violation',
#    'certificate',
#    'sent',
#    'everyone',
#    'misdemeanor',
#    'minimum']),
#  (False,
#   ['great',
#    'time',
#    'reading',
#    'ana',
#    'iguana',
#    'first',
#    'grader',
#    'lake',
#    'anne',
#    'elementary',
#    'talking']),
#  (False,
#   ['outlined',
#    'senate',
#    'agenda',
#    'stopgunviolence',
#    'ramp',
#    'pressure',
#    'pas',
#    'new',
#    'gun',
#    'safety',
#    'law']),
#  (False,
#   ['hardball',
#    'hillary',
#    'big',
#    'time',
#    'wa',
#    'shut',
#    'hardballchris',
#    'debatenight']),
#  (False, ['thank', 'berniesanders', 'proud', 'fight', 'alongside']),
#  (False,
#   ['check',
#    'latest',
#    'medium',
#    'story',
#    'senate',
#    'help',
#    'prevent',
#    'sexual',
#    'assault',
#    'passing',
#    'ecaa']),
#  (False,
#   ['welcome',
#    'announcement',
#    'u',
#    'coordinator',
#    'irandeal',
#    'implementation',
#    'vigilant',
#    'oversight',
#    'enforcement',
#    'essential',
#    'amb',
#    'mull',
#    'key']),
#  (True,
#   ['behind',
#    'scene',
#    'look',
#    'gop',
#    'chairman',
#    'reince',
#    'reshaping',
#    'gopdebates']),
#  (False,
#   ['thank',
#    'potus',
#    'making',
#    'sure',
#    'million',
#    'american',
#    'receive',
#    'overtime',
#    'pay',
#    'deserve',
#    'h']),
#  (False,
#   ['hillaryclinton',
#    'protect',
#    'gain',
#    'weve',
#    'made',
#    'lgbt',
#    'right',
#    'woman',
#    'right',
#    'expand']),
#  (True,
#   ['proud',
#    'welcome',
#    'pope',
#    'francis',
#    'washington',
#    'c',
#    'today',
#    'popeindc']),
#  (False,
#   ['spent',
#    'life',
#    'trying',
#    'stay',
#    'far',
#    'away',
#    'working',
#    'people',
#    'could',
#    'potus',
#    'trump']),
#  (False,
#   ['michelle',
#    'obama',
#    'last',
#    'chance',
#    'get',
#    'limited',
#    'edition',
#    'sticker']),
#  (False,
#   ['sensanders',
#    'time',
#    'massive',
#    'income',
#    'wealth',
#    'inequality',
#    'absurd',
#    'provide',
#    'huge',
#    'tax',
#    'break',
#    'rich']),
#  (False,
#   ['congrats',
#    'kmurphyva',
#    'va34',
#    'victory',
#    'experience',
#    'community',
#    'leadership',
#    'passion',
#    'education',
#    'serve',
#    'va',
#    'well']),
#  (False,
#   ['hfa', 'hillary', 'oldest', 'delegate', '102', 'read', 'jerry', 'story']),
#  (False,
#   ['common',
#    'sense',
#    'solution',
#    'stopgunviolence',
#    'close',
#    'gun',
#    'show',
#    'loophole',
#    'improve',
#    'expand',
#    'background',
#    'check',
#    'shut',
#    'pipeline',
#    'illegal',
#    'gun']),
#  (False,
#   ['dncwomen',
#    'trump',
#    'maternity',
#    'leave',
#    'plan',
#    'insult',
#    'woman',
#    'men',
#    'child']),
#  (True, ['follow', 'along', 'instagram', 'behind', 'scene', 'look']),
#  (False,
#   ['heading',
#    '95',
#    'express',
#    'lane',
#    'ribbon',
#    'cutting',
#    'alexandria',
#    'proud',
#    'started',
#    'important',
#    'infrastructure',
#    'project',
#    'governor']),
#  (False,
#   ['whitehouse',
#    'enough',
#    'time',
#    'senate',
#    'consider',
#    'record',
#    'nominee',
#    'present',
#    'potus',
#    'supreme',
#    'court',
#    'v']),
#  (True,
#   ['wa',
#    'asked',
#    'healthcare',
#    'anderson',
#    'cooper',
#    'consistent',
#    'repeal',
#    'obamacare',
#    'including',
#    'mandate',
#    'period']),
#  (False,
#   ['weve',
#    'got',
#    'serious',
#    'work',
#    'ahead',
#    'addressing',
#    'problem',
#    'criminal',
#    'justice',
#    'system']),
#  (False,
#   ['healthcaregov',
#    'need',
#    'health',
#    'insurance',
#    'still',
#    'time',
#    'start',
#    'getcovered']),
#  (False,
#   ['trump', 'ha', 'repeatedly', 'lied', 'donation', 'veteran', 'charity']),
#  (False,
#   ['terrible',
#    'news',
#    'richmond',
#    'today',
#    'praying',
#    'wounded',
#    'greyhound',
#    'station',
#    'first',
#    'responder']),
#  (False,
#   ['short',
#    'term',
#    'funding',
#    'patch',
#    'cant',
#    'fix',
#    'long',
#    'term',
#    'infrastructure',
#    'problem',
#    'memorialbridge',
#    '4',
#    '800',
#    'va',
#    'bridge',
#    'need',
#    'work']),
#  (False,
#   ['great',
#    'tour',
#    'fort',
#    'eustis',
#    'state',
#    'art',
#    'simulator',
#    'provide',
#    'servicemembers']),
#  (False,
#   ['llcdillon',
#    'running',
#    'president',
#    'hasnt',
#    'stopped',
#    'trump',
#    'choosing',
#    'foreign',
#    'worker',
#    'american',
#    'c']),
#  (True,
#   ['ltjohnvick',
#    'tonight',
#    'reached',
#    '304',
#    'home',
#    'george',
#    'washington',
#    'h',
#    'mercer',
#    'hometown',
#    'leadright2016']),
#  (False,
#   ['pretty',
#    'obvious',
#    'doesnt',
#    'know',
#    'lot',
#    'issue',
#    'senatemajldr',
#    'trump',
#    'couldnt',
#    'agree',
#    'mitch']),
#  (True,
#   ['nationalffa',
#    'flag',
#    'blue',
#    'gold',
#    'ffa',
#    'belongs',
#    'indiana',
#    'govpencein',
#    'announcing',
#    'national',
#    'convention',
#    'indy',
#    'extension']),
#  (True,
#   ['star',
#    'reboot',
#    'liar',
#    'liar',
#    'hillary',
#    'clinton',
#    'ted',
#    'cruz',
#    'let',
#    'know']),
#  (False,
#   ['story',
#    'rodhams',
#    'bidens',
#    'isnt',
#    'unique',
#    'unique',
#    'country',
#    'story',
#    'written']),
#  (False,
#   ['opioid',
#    'addiction',
#    'destroying',
#    'many',
#    'life',
#    'across',
#    'country',
#    'time',
#    'end',
#    'epidemic']),
#  (False, ['say', 'youre', 'voting', 'democrat']),
#  (True,
#   ['lgholcomb',
#    'veteran',
#    'safe',
#    'place',
#    'live',
#    'thanks',
#    'effort',
#    'cshinfo',
#    'teamgaryindiana',
#    'ihcda',
#    'others',
#    'f']),
#  (True, ['interviewed', 'foxandfriends', '7', '30', 'enjoy']),
#  (True,
#   ['american',
#    'many',
#    'top',
#    'dems',
#    'oppose',
#    'dangerous',
#    'irandeal',
#    'tell',
#    'obama',
#    'hillary',
#    'listen']),
#  (True,
#   ['clinton', 'voted', 'kill', 'immigration', 'reform', '2007', 'demdebate']),
#  (False,
#   ['whlive',
#    'spent',
#    'every',
#    'single',
#    'day',
#    'presidency',
#    'focused',
#    'grow',
#    'middle',
#    'class',
#    'increase',
#    'job',
#    'boost',
#    'wage']),
#  (False,
#   ['excited',
#    'deliver',
#    'commencement',
#    'address',
#    'vminews',
#    'class',
#    '2016',
#    'watch',
#    'live',
#    '11',
#    '00am']),
#  (True,
#   ['honored',
#    'received',
#    'endorsement',
#    'lou',
#    'holtz',
#    'great',
#    'guy',
#    'inprimary',
#    'trump2016']),
#  (False,
#   ['veteran',
#    'day',
#    'let',
#    'say',
#    'welcomehome',
#    'thank',
#    'service',
#    'sacrifice',
#    'generation',
#    'war',
#    '13',
#    'year']),
#  (True,
#   ['obama',
#    'ha',
#    'criticized',
#    'clinton',
#    'failed',
#    'legacy',
#    'libya',
#    'demdebate']),
#  (False,
#   ['tune',
#    'fox5newsdc',
#    '7',
#    '30am',
#    'interview',
#    'stevechenevey',
#    'fox5dcallison',
#    'teachsafe',
#    'relationship',
#    'act']),
#  (False, ['fridayfeeling']),
#  (False, ['hfa', 'story', 'behind', 'campaign', 'first', 'braille', 'button']),
#  (False,
#   ['loved',
#    'spending',
#    'fun',
#    'mother',
#    'day',
#    'weekend',
#    'anne',
#    'grateful',
#    'mom',
#    'kathy',
#    'extraordinary',
#    'mom']),
#  (False,
#   ['look',
#    'gold',
#    'star',
#    'family',
#    'see',
#    'muslim',
#    'patriotic',
#    'american',
#    'hillary',
#    'trump']),
#  (False,
#   ['nuestra',
#    'relaci',
#    'n',
#    'con',
#    'cuba',
#    'va',
#    'cambiar',
#    'de',
#    'un',
#    'al',
#    'otro',
#    'pero',
#    'el',
#    'di',
#    'logo',
#    'abierto',
#    'e',
#    'eficaz',
#    'que',
#    'el',
#    'aislamiento']),
#  (False, ['read', 'full', 'statement', 'fy2016', 'defense', 'bill', 'ndaa']),
#  (False,
#   ['want',
#    'sure',
#    'hillary',
#    'clinton',
#    'take',
#    'oath',
#    'office',
#    'donald',
#    'trump',
#    'jerrybrowngov']),
#  (True, ['amazon', 'add', '2', '100', 'job', 'indiana', 'read']),
#  (False,
#   ['eid',
#    'mubarak',
#    'wishing',
#    'joyous',
#    'eid',
#    'al',
#    'fitr',
#    'muslim',
#    'around',
#    'world',
#    'today']),
#  (False,
#   ['dwstweets',
#    'minute',
#    'republican',
#    'meet',
#    'gopdebate',
#    'moment',
#    'tell',
#    'u',
#    'plan',
#    'lead',
#    'th']),
#  (False,
#   ['tune',
#    '8am',
#    'wavy',
#    'news',
#    'ill',
#    'join',
#    'katiewavy',
#    'robert',
#    'discus',
#    'bill',
#    'passed',
#    'last',
#    'night',
#    'help',
#    'reform',
#    'va']),
#  (True, ['inspiring', 'fellow', 'ready', 'leadright2016', 'find']),
#  (True, ['one', 'year', 'today']),
#  (False,
#   ['finally',
#    'opportunity',
#    'engage',
#    'meaningful',
#    'public',
#    'debate',
#    'u',
#    'military',
#    'mission',
#    'isil']),
#  (False, ['hfa', 'lifting', 'tearing']),
#  (False,
#   ['deeply',
#    'saddened',
#    'hear',
#    'chief',
#    'bryant',
#    'passing',
#    'wa',
#    'strong',
#    'leader',
#    'monocan',
#    'people',
#    'pioneer',
#    'woman']),
#  (True,
#   ['bernie',
#    'sander',
#    'endorsing',
#    'crooked',
#    'hillary',
#    'clinton',
#    'like',
#    'occupy',
#    'wall',
#    'street',
#    'endorsing',
#    'goldman',
#    'sachs']),
#  (False,
#   ['hfa',
#    'must',
#    'force',
#    'unity',
#    'america',
#    'vision',
#    'includes',
#    'u',
#    'gen',
#    'john',
#    'allen',
#    'dnc',
#    'ayi3h0mr']),
#  (True,
#   ['fight',
#    'protect',
#    'hoosier',
#    'job',
#    'unfair',
#    'trade',
#    'practice',
#    'china']),
#  (True,
#   ['thanks',
#    'hillaryclinton',
#    'failed',
#    'policy',
#    'isi',
#    'continues',
#    'endanger',
#    'american',
#    'home',
#    'abroad']),
#  (True,
#   ['tbt',
#    'hillary',
#    'clinton',
#    'ran',
#    '2008',
#    'two',
#    'biggest',
#    'fundraiser',
#    'conducting',
#    'massive',
#    'ponzi',
#    'scheme']),
#  (False,
#   ['remain',
#    'committed',
#    'fully',
#    'restoring',
#    'vra',
#    'hope',
#    'congress',
#    'work',
#    'bipartisan',
#    'way',
#    'give',
#    'citizen',
#    'protection',
#    'need',
#    'vra50']),
#  (True, ['watching', 'tonight', 'gopdebate']),
#  (False,
#   ['build',
#    'cleaner',
#    'resilient',
#    'electrical',
#    'grid',
#    'enough',
#    'renewable',
#    'energy',
#    'power',
#    'every',
#    'home',
#    'country']),
#  (False,
#   ['praying', 'wounded', 'aftermath', 'today', 'bus', 'bombing', 'jerusalem']),
#  (False,
#   ['plan',
#    'vote',
#    'keystonexl',
#    'pipeline',
#    'heading',
#    'senate',
#    'floor',
#    'soon',
#    'explain',
#    'tune']),
#  (True, ['teampence', 'volunteer', 'indiana', 'supersaturday']),
#  (True, ['hillary', 'cave', 'keystonexl', 'cant', 'trust', 'white', 'house']),
#  (False,
#   ['stand',
#    'tonight',
#    'almost',
#    'two',
#    'term',
#    'president',
#    'tell',
#    'even',
#    'optimistic',
#    'future',
#    'potus']),
#  (True,
#   ['tennessee',
#    'gop',
#    'poll',
#    'trump',
#    '32',
#    '7',
#    'cruz',
#    '16',
#    '5',
#    'carson',
#    '6',
#    '6',
#    'rubio',
#    '5',
#    '3',
#    'christie',
#    '2',
#    '4',
#    'jeb',
#    '1',
#    '6']),
#  (False,
#   ['fear',
#    'future',
#    'shape',
#    'embrace',
#    'one',
#    'people',
#    'strongertogether',
#    'pres',
#    'obama',
#    'demsinphilly']),
#  (False,
#   ['settling',
#    'new',
#    'dc',
#    'office',
#    'space',
#    'wk',
#    'come',
#    'visit',
#    '231',
#    'russell',
#    'casework',
#    'help',
#    'question',
#    'click']),
#  (False,
#   ['everyvoice',
#    'every',
#    'voice',
#    'proud',
#    'endorse',
#    'hillaryclinton',
#    'president']),
#  (True,
#   ['govpencein',
#    'today',
#    'mark',
#    '199th',
#    'anniversary',
#    'joining',
#    'union',
#    'take',
#    'part',
#    'celebrating',
#    'statehood',
#    'day',
#    'tvf9hj8']),
#  (False,
#   ['leaving',
#    'field',
#    '2016',
#    'help',
#    'u',
#    'ensure',
#    'next',
#    'president',
#    'democrat']),
#  (True,
#   ['clinton',
#    'corruption',
#    'sabotage',
#    'inner',
#    'city',
#    'full',
#    'speech',
#    'transcript']),
#  (True,
#   ['fox',
#    'debate',
#    'advertising',
#    'rate',
#    'falling',
#    'like',
#    'rock',
#    'tune',
#    'special',
#    'event',
#    'veteran',
#    '9pm',
#    'est']),
#  ...]

# %%
from collections import Counter
count = Counter()
for d in data_train:
    count.update(d[1])

# %% [markdown]
# ## 2. Feature Construction
#
# The next step is to derive feature vectors from the tokenized tweets. In this section, you will be constructing a bag-of-words [TF-IDF](https://en.wikipedia.org/wiki/Tf%E2%80%93idf) feature vector.
#
# The number of possible words is prohibitively large, and not all words are useful for our task. We will begin by filtering the vectors using a common heuristic:
#
# We calculate a frequency distribution of words in the corpus, and remove words at the head (most frequent) and tail (least frequent) of the distribution. Most frequently used words (often called stopwords) provide very little information about the similarity of two pieces of text; we have already removed these. Words with extremely low frequency tend to be typos.
#
# We will now implement a function which counts the number of times that each token is used in the training corpus. You should return a [`collections.Counter`](https://docs.python.org/3/library/collections.html#collections.Counter) object with the number of times that each word appears in the dataset.
#
# (This should take no more than 20s to run, including reading the files.)

# %%
from collections import Counter
def get_distribution_test(get_distribution):
    data_train, data_test = read_data()
    dist = get_distribution(data_train)
    test.true(isinstance(dist, collections.Counter))
    if dist is None:
        return

    test.equal(dist['trump'], 1812)
    test.equal(dist['clinton'], 1107)
    test.equal(dist['president'], 788)
    test.equal(dist['american'], 745)
    test.equal(dist['job'], 676)
    test.equal(dist['obama'], 438)
    test.equal(dist['hoosier'], 393)

    plt.hist(dist.values(), bins=100)
    plt.yscale('log')

@test
def get_distribution(data_train):
    """ Calculates the word count distribution, excluding stopwords.

    args: 
        data_train -- the training data

    return : collections.Counter -- the distribution of word counts
    """
    count = Counter()
    for d in data_train:
        count.update(d[1])
    return count
    pass
# Out:
# ### TESTING get_distribution: PASSED 8/8
# ###

# %% [markdown]
# Notice the distribution looks exponential, even with a logarithmic y-axis; there are a lot words that appear only once. Lets figure out what these words are so we can eliminate them from the dataset.

# %%
def get_rare_words_test(get_rare_words):
    data_train, data_test = read_data()
    dist = get_distribution(data_train)
    new_stopwords = get_rare_words(dist)

    test.equal(len(new_stopwords), 8048)
    test.true("fugedaboudit" in new_stopwords)
    test.true("puppybowl" in new_stopwords)
    test.true("rusty" in new_stopwords)    

@test
def get_rare_words(dist):
    """use the word count information from the training data to find more stopwords

    args:
        dist: collections.Counter -- the output of get_distribution

    returns : Set[str] -- a set of all words that appear exactly once in the training data
    """
    f = open('D:/hw3_output.txt','w')

    once= set()
    for k,v in dist.items():
        if v==1:
            once.add(k)
    l=sorted(once)
    for i in l:
        f.writelines(i)
        f.write('\n')
    
    f.close()
    return once
    pass
# Out:
# ### TESTING get_rare_words: PASSED 4/4
# ###

# %% [markdown]
# Here we provide a wrapper function to cache the preprocessed data. This helps it not take quite as long to re-run. If you change anything above this cell, re-run this cell to clear the cache.

# %%
global PREPROCESSED_DATA_CACHE
PREPROCESSED_DATA_CACHE = None

def get_data():
    global PREPROCESSED_DATA_CACHE
    if PREPROCESSED_DATA_CACHE is None:
        data_train, data_test = read_data()
        dist = get_distribution(data_train)
        new_stopwords = get_rare_words(dist)
        PREPROCESSED_DATA_CACHE = read_data(new_stopwords)

    return PREPROCESSED_DATA_CACHE

# %% [markdown]
# ### Vectorizing
#
# Now we have each tweet as a list of words, excluding words with high- and low-frequencies. We want to convert these into a sparse feature matrix, where each row corresponds to a tweet and each column to a possible word. We can use `scikit-learn`'s [`TfidfVectorizer`](https://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.TfidfVectorizer.html) to do this quite easily.
#
# There's a catch, though: `TfidfVectorizer` expects the input to be a string, and (by default) it perfoms its own analyzing. You have to override that behavior by passing in `do_nothing` to the constructor as an optional parameter.
#
# Hints:
#
#  - Read [the documentation](https://scikit-learn.org/stable/modules/feature_extraction.html#customizing-the-vectorizer-classes) carefully, and then this [blog post](http://www.davidsbatista.net/blog/2018/02/28/TfidfVectorizer/) ([mirror](http://archive.is/pVdqE)). You need to pass in `do_nothing` in two locations.
#  - You should use just the training data to `fit` or `fit_transform` the vectorizer.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
# Helper function, do not change:
def do_nothing(x):
    return x

def create_features_test(create_features):
    train_features, train_labels, test_features = create_features(*get_data())

    test.equal(repr(train_features), """<17298x8714 sparse matrix of type '<class 'numpy.float64'>'
	with 161480 stored elements in Compressed Sparse Row format>""")

    test.equal(repr(test_features), """<1000x8714 sparse matrix of type '<class 'numpy.float64'>'
	with 9037 stored elements in Compressed Sparse Row format>""")

    test.equal(train_labels.dtype, bool)
    test.equal(len(train_labels), 17298)
    test.equal(sum(train_labels), 8646)

@test
def create_features(train_data, test_data):
    """creates the feature matrices and label vector for the training and test sets.

    args:
        train_data : List[Tuple[is_republican, tweet_words]]
            is_republican : bool -- True if Republican, False otherwise
            tweet_words : List[str] -- the processed tweet tokens
        test_data : List[List[str]] -- a list of processed tweets

    returns: Tuple[train_features, train_labels, test_features]
        train_features : scipy.sparse.csr.csr_matrix -- feature matrix for the training set
        train_labels : np.array[num_train] -- a numpy vector, where 1 stands for Republican and 0 stands for Democrat 
        test_features : scipy.sparse.csr.csr_matrix -- feature matrix for the test set
    """
    def dummy_fun(doc):
        return doc

    tfidf = TfidfVectorizer(
        analyzer='word',
        tokenizer=dummy_fun,
        preprocessor=dummy_fun,
        token_pattern=None)
#     tfidf = TfidfVectorizer()
    trainset=[]
    testset=[]
    label=[]
    for d in train_data:
        trainset.append(d[1])
        if d[0]==True:
            label.append(1)
        elif d[0]==False:
            label.append(0)
        
    for d in test_data:
        testset.append(d)
    print(trainset)
    train_features = tfidf.fit_transform(trainset)
    test_features = tfidf.transform(testset)
    array1 = np.array(label)
    labels = [True if array1[i]==1 else False for i in range(len(array1))]
    train_labels = np.array(labels)
    return (train_features, train_labels, test_features)
# Out:
# [['gopconvention', 'oregon', 'vote', 'today', 'mean', '62', 'day', 'gopconvention'], ['dwstweets', 'choice', '2016', 'clear', 'need', 'another', 'democrat', 'white', 'house', 'demdebate', 'wearedemocrats'], ['trump', 'calling', 'trillion', 'dollar', 'tax', 'cut', 'wall', 'street', 'time', 'pay', 'fair', 'share'], ['timkaine', 'guiding', 'principle', 'belief', 'make', 'difference', 'public', 'service'], ['glad', 'senate', 'could', 'pas', 'approps', 'bill', 'solid', 'provision', 'virginia'], ['indythisweek', 'rtv6', 'exclusive', 'govpencein', 'sits', 'rafaelontv', 'see', 'sunday', 'morning', '8', 'rtv6', 'rtv6', 'app'], ['chatham', 'town', 'council', 'congress', 'reproberthurt', 'ha', 'made', 'strong', 'mark', 'community', 'proud', 'work', 'together', 'behalf', 'va'], ['thank', 'new', 'louisiana', 'makeamericagreatagain', 'votetrump'], ['realdonaldtrump', 'happy', '241st', 'birthday', 'usarmy', 'thank'], ['govpencein', 'excited', 'announce', 'today', 'plan', 'build', 'indiana', 'neuro', 'diagnostic', 'institute', 'partnership', 'w', 'chnw'], ['sensanders', 'dad', 'wa', 'born', 'know', 'many', 'people', 'ever', 'asked', 'whether', 'wa', 'born', 'america', 'nobody', 'ever'], ['positive', 'relationship', 'faith', 'group', 'law', 'enforcement', 'build', 'resilient', 'community'], [], ['welcomed', 'tour', 'rva', 'morning', 'talk', 'innovation', 'talent', 'entrepreneurial', 'drive'], ['take', 'president', 'republican', 'party', 'dangerously', 'extreme', 'betterthanthis'], ['watching', 'demdebate', 'dont', 'dont', 'want'], ['next', 'president', 'spouse', 'big', 'job', 'campaign', 'trail', 'white', 'house', 'billclinton'], ['obama', 'losing', 'credibility', 'syrian', 'opposition', 'leader'], ['congratulation', 'judge', 'hannah', 'lauck', 'virginia', 'confirmed', 'eastern', 'district', 'court', '90', '0', 'vote'], ['wrote', 'usindianaffairs', 'calling', 'flexibility', 'federal', 'recognition', 'process', 'indian', 'tribe', 'unusual', 'circumstance'], ['congrats', 'va', 'national', 'guard', 'wwii', 'army', 'veteran', 'decorated', 'knight', 'legion', 'honor', 'french', 'government'], ['leaving', 'new', 'hampshire', 'big', 'crowd', 'looking', 'forward', 'fitn'], ['congrats', 'finalfive', 'outstanding', 'performance', 'rio', 'special', 'congrats', 'virginia', 'native'], ['governorva', 'morning', 'gov', 'signed', 'taking', 'executive', 'action', 'keep', 'gun', 'dangerous', 'hand'], ['tune', 'wamu885', 'morning', 'commute', 'interview', 'w', 'kid', 'fleeing', 'violence', 'honduras'], ['lakeannees', 'senator', 'tim', 'kaine', 'read', 'spanish', '3rd', 'grade', 'spanish', 'class', 'today', 'hispanicheritagemonth'], ['foxandfriends', '7', '00', 'enjoy'], ['drjamescabot', 'realdonaldtrump', 'danscavino', 'carolde', 'checked', 'wallet', 'lately', 'mr', 'ailes'], ['heading', 'senate', 'floor', 'make', 'case', 'keystonexl', 'watch', 'speech', 'live'], ['timkaine', 'falsely', 'claim', 'clintonfdn', 'already', 'stopped', 'taking', 'foreign', 'corporate'], ['great', 'roanoke', 'next', 'citizen', 'day', 'clean', 'blue', 'ridge', 'join', 'u', 'mile', '114', '9'], ['donald', 'trump', 'launched', 'campaign', 'one', 'year', 'ago', 'week', 'year'], ['show', 'friend', 'party', 'creates', 'job', 'spoiler', 'isnt', 'trump', 'gop'], ['good', 'news', 'finally', 'got', 'republican', 'interested', 'woman', 'health', 'hillary'], ['whitehouse', 'happening', 'question', 'potus', 'final', 'state', 'union'], ['learned', 'family', 'methodist', 'faith', 'called', 'good', 'people', 'hillary'], ['govpencein', 'never', 'fully', 'debt', 'deputy', 'koontz', 'service', 'county', 'state', 'nation', 'h'], ['study', 'show', 'rate', 'sea', 'level', 'rise', 'pose', 'serious', 'challenge', 'hampton', 'road', 'actonclimate'], ['abcpolitics', 'mike', 'penny', 'clinton', 'deleted', 'email', 'doesnt', 'look', 'like', 'politics', 'folk', 'look', 'like', 'obstruction'], ['landed', 'baton', 'rouge', 'louisiana', 'report', 'line', 'three', 'quarter', 'mile', 'get', 'wow', 'makeamericagreataga ...
# ### TESTING create_features: PASSED 5/5
# ###

# %% [markdown]
# Observe that the created matrices are very sparse.
#
# Now that we have the features, lets perform the classification:

# %% [markdown]
# ## 3. Classification
#
# We are ready to put it all together and train the classification model.
#
# You will be will be using the Support Vector Machine [`sklearn.svm.SVC`](http://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html#sklearn.svm.SVC). [Here](http://docs.opencv.org/2.4/doc/tutorials/ml/introduction_to_svm/introduction_to_svm.html) is a quick introduction to SVMs.
#
# At the heart of an SVM is the concept of a _kernel function_, which determines the distance between two data points. `sklearn.svm.SVC` natively supports four kernel functions: `linear`, `poly`, `rbf`, `sigmoid`. For this problem space, we will use the `linear` kernel.
#
# In this section, we will:
#
# 1. build a classifier using the `linear` kernel,
# 2. train it using the training set,
# 3. evaluate the trained model on the training set, and then
# 4. use it to predict classification on our test set.
#
# Let's begin by training a classifier. This should take no more than 20s to run. You should set the optional parameter `gamma` to `auto`, but leave the rest at their default values.

# %%
from sklearn.svm import SVC
def learn_classifier_test(learn_classifier):
    train_features, train_labels, _ = create_features(*get_data())
    classifier = learn_classifier(train_features, train_labels)

    test.equal(repr(classifier).replace("\n", "").replace("  ", " "), """SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0, decision_function_shape='ovr', degree=3, gamma='auto', kernel='linear', max_iter=-1, probability=False, random_state=None, shrinking=True, tol=0.001, verbose=False)""")

@test
def learn_classifier(train_features, train_labels, kernel="linear"):
    """learns a classifier from the input features and labels using a specified kernel function

    args:
        train_features: scipy.sparse.csr.csr_matrix -- sparse matrix of features
        train_labels : numpy.ndarray(bool): binary vector of class labels
        kernel : str -- kernel function to be used with classifier, must be (linear|poly|rbf|sigmoid)

    return : sklearn.svm.classes.SVC -- classifier
    """
    clf = SVC(kernel=kernel, gamma='auto')
    assert kernel in ["linear", "poly", "rbf", "sigmoid"]
    return clf
    pass # Implement this.
# Out:
# ### TESTING learn_classifier: PASSED 1/1
# ###

# %% [markdown]
# Now that we know how to train a classifier, the next step is to measure its performance. This step is necessary to select the best model among a given set of models, or even tune hyperparameters for a given model.
#
# We would ordinarily use a held-out validation set to evaluate the performance of the classifier. The use of a held-out set prevents overfitting to the data, and you will do this for another assignment. For this problem, though, we can use the training set.
#
# To measure classification accuracy we will use the [$F_1$ score](https://en.wikipedia.org/wiki/F1_score). Implement this:

# %%
def f1_test(f1):
    test.equal(f1([1,1,1], [1,1,1]), 1.0)
    test.equal(f1([1,0,0], [1,0,0]), 1.0)
    test.equal(f1([1,1,0], [1,1,1]), 0.8)
    test.equal(f1([1,0,0], [1,1,0]), 2/3)
    test.equal(f1([0,0,1], [1,0,1]), 2/3)
    test.equal(f1([1,0,0], [1,1,1]), 0.5)

@test
def f1(pred, ground):
    """ evaluates a classifier based on a supplied validation data

    args:
        pred: numpy.ndarray(bool) -- predictions
        ground: numpy.ndarray(bool) -- known ground-truth values
    
    return : double -- the F1 score of the predictions
    """
    pred = np.array(pred, dtype=bool)
    ground = np.array(ground, dtype=bool)
    true_p=0
#     true_n=0
    false_p=0
    false_n=0
    for i in range(len(pred)):
        if (pred[i]==True) & (pred[i]==ground[i]):
            true_p=true_p+1
        elif (pred[i]==True) & (pred[i]!=ground[i]):
            false_p=false_p+1
        elif (pred[i]==False) & (pred[i]!=ground[i]):
            false_n=false_n+1
    precision=true_p/(true_p+false_p)
    recall=true_p/(true_p+false_n)
    f1=2*precision*recall/(precision+recall)
    return f1
    pass # Implement this
# Out:
# ### TESTING f1: PASSED 6/6
# ###

# %% [markdown]
# Now we calculate the F1 score on the training set:

# %%
def evaluate_test(evaluate):
    train_features, train_labels, _ = create_features(*get_data())
    test.true(np.abs(evaluate(train_features, train_labels, 'linear') - 0.9538984242282234) < 1e-5)

@test
def evaluate(train_features, train_labels, kernel="linear"):
    """train the classifier and report the F1 score on the training set
    
    args:
        train_features: scipy.sparse.csr.csr_matrix -- sparse matrix of features
        train_labels : numpy.ndarray(bool): binary vector of class labels
        kernel : str -- kernel function to be used with classifier, must be (linear|poly|rbf|sigmoid)

    return : double -- the F1 score of the predictions on the training labels
    """
    clf=learn_classifier(train_features, train_labels, kernel="linear")
    clf.fit(train_features, train_labels)
    pred=clf.predict(train_features)
    f1_score=f1(pred, train_labels)
    return f1_score
# Out:
# ### TESTING evaluate: PASSED 1/1
# ###

# %% [markdown]
# ### Classifying Test Tweets
#
# Home stretch! Now we can classify the test tweets! Use `learn_classifier` to make a trained classifier and predict the labels given the `test_features`.

# %%
def pp(entries):
    from IPython.display import HTML, display
    import tabulate

    display(HTML(tabulate.tabulate([(f'<b>{"R" if isr else "D"}</b>', txt[0]) for isr, txt in entries], tablefmt='html')))

def classify_tweets_test(classify_tweets):
    test_original = read_csv("tweets_test")
    train_features, train_labels, test_features = create_features(*get_data())
    test_classes = classify_tweets(train_features, train_labels, test_features)

    pp([e for i, e in enumerate(zip(test_classes, test_original)) if i in [0, 2, 9, 70, 654, 723]])

@test
def classify_tweets(train_features, train_labels, test_features):
    """Train a model and predict class labels for the test set.

    args:
        train_features: scipy.sparse.csr.csr_matrix -- sparse matrix of features
        train_labels : numpy.ndarray(bool): binary vector of class labels
        test_features: scipy.sparse.csr.csr_matrix -- sparse matrix of features, test set

    return : numpy.ndarray[bool] -- True if the corresponding tweet is predicted to be Republican, False otherwise.
    """
    clf=learn_classifier(train_features, train_labels, kernel="linear")
    clf.fit(train_features, train_labels)
    pred=clf.predict(test_features)
    return pred
# Out:
# <table>
# <tbody>
# <tr><td><b>D</b></td><td>A comprehensive look at the many lies and offenses of Donald Trump: https://t.co/HKY6HxxFUX https://t.co/cF5GsywU3f                            </td></tr>
# <tr><td><b>D</b></td><td>"I’m here as a proud American, a proud Democrat, a proud mother, and tonight, in particular, a very, very proud daughter.” —@ChelseaClinton    </td></tr>
# <tr><td><b>R</b></td><td>Oops! Clinton confuses the Constitution with the Declaration of Independence &amp; backs a constitutional right to life.
# https://t.co/gG6xbptUyo                                                                                                                                                </td></tr>
# <tr><td><b>R</b></td><td>Secret Server you need to wipe clean? http://t.co/oHlxKqImWB Get Hillary's Secret Server Wiper today. http://t.co/ANbo9R6Qwt                   </td></tr>
# <tr><td><b>D</b></td><td>"My dad ran a union ironworking shop...my mom was his best salesman. My brothers &amp; I pitched in...that's how small family businesses do it"</td></tr>
# <tr><td><b>D</b></td><td>Thomas Jefferson loved vanilla ice cream. He brought home a recipe from France, which is now in the @librarycongress #VAisForPresidents        </td></tr>
# </tbody>
# </table>
# ### TESTING classify_tweets: PASSED 0/0
# ###
